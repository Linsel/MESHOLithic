# %%
from mesh import Mesh
#from gaussian_map_3 import Gaussian_Map
from gaussian_map import Gaussian_Map

import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import pymeshlab
# Import Jan's label writer
import python_libs.write_labels_txt as jan

# import time

# %%
path = '/home/linsel/Documents/PhD/Data/Fumane/annotated/coloured/curvature_orientated/'

# name = '31'#"31.comp.1"

# filename,quality_index = path + name + '.ply',3

# %%
quality_index = 3
for filename in os.listdir(path):
    print (filename)
    GM_1 = Gaussian_Map()
    GM_1.load_ply(path + filename, quality_index)
    GM_1.create_point_cloud()
    GM_1.prep_orientate_mesh_pca ()
    GM_1.prep_orientate_mesh_Kmeans ()   
    GM_1.save_exp_cloud ()
    GM_1.export_exp_cloud_as_mesh ()
    GM_1.recalculate_normals ()
# Out:
# Time read data file: 5.249349763995269
# Time read and prepare data: 21.595689420006238
# Time writing label txt file: 0.11592966501484625
# Time read data file: 1.4215106010087766
# Time read and prepare data: 5.934260651003569
# Time writing label txt file: 0.03869223999208771
# Time read data file: 0.9878107440017629
# Time read and prepare data: 3.734980187000474
# Time writing label txt file: 0.02939190500183031
# Time read data file: 5.4341449399944395
# Time read and prepare data: 22.370929911005078
# Time writing label txt file: 0.13360716300667264
# Time read data file: 1.7177499170065857
# Time read and prepare data: 6.093053635995602
# Time writing label txt file: 0.04489355400437489
# Time read data file: 3.2146100090176333
# Time read and prepare data: 12.460257983009797
# Time writing label txt file: 0.07764714400400408
# Time read data file: 4.874447958980454
# Time read and prepare data: 18.970435472001554
# Time writing label txt file: 0.11075099601293914
# Time read data file: 5.179224825988058
# Time read and prepare data: 21.515755088999867
# Time writing label txt file: 0.12144679899211042
# Time read data file: 5.445778417983092
# Time read and prepare data: 23.083385285019176
# Time writing label txt file: 0.12551738999900408
# Time read data file: 5.540049636998447
# Time read and prepare data: 22.107453294011066
# Time writing label txt file: 0.12771918199723586
# Time read data file: 5.68072621099418
# Time read and prepare data: 22.5681428029784
# Time writing label txt file: 0.12705505898338743
# Time read data file: 5.527020042005461
# Time read and prepare data: 21.997654783015605
# Time writing label txt file: 0.12675865599885583
# Time read data file: 5.516301714989822
# Time read and prepare data: 22.569432041986147
# Time writing label txt file: 0.12846873499802314
# Time read data file: 4.177346215990838
# Time read and prepare data: 17.77256919001229
# Time writing label txt file: 0.09763955700327642
# Time read data file: 4.122029232006753
# Time read and prepare data: 15.566695062996587
# Time writing label txt file: 0.09531292400788516
# Time read data file: 5.5858514229767025
# Time read and prepare data: 22.02538949000882
# Time writing label txt file: 0.12068954500136897
# Time read data file: 5.412792287010234
# Time read and prepare data: 21.161067301989533
# Time writing label txt file: 0.1403604699880816
# Time read data file: 0.5724782320030499
# Time read and prepare data: 2.101619105989812
# Time writing label txt file: 0.018569392996141687
# Time read data file: 5.604317781020654
# Time read and prepare data: 22.524653697008034
# Time writing label txt file: 0.12336140000843443
# Time read data file: 4.634107568999752
# Time read and prepare data: 18.578301216010004
# Time writing label txt file: 0.100394012988545
# Time read data file: 0.23713860000134446
# Time read and prepare data: 0.9752282050030772
# Time writing label txt file: 0.0076363580010365695
# Time read data file: 5.258475486014504
# Time read and prepare data: 21.68963316301233
# Time writing label txt file: 0.12211193499388173
# Time read data file: 5.425002705014776
# Time read and prepare data: 20.93475959301577
# Time writing label txt file: 0.12204654101515189
# Time read data file: 4.819265822006855
# Time read and prepare data: 19.590182647982147
# Time writing label txt file: 0.11165092801093124
# Time read data file: 8.690842337004142
# Time read and prepare data: 34.60514127500937
# Time writing label txt file: 0.19427630899008363
# Time read data file: 5.391699625994079
# Time read and prepare data: 21.67914564302191
# Time writing label txt file: 0.12433571298606694
# Time read data file: 4.113956320012221
# Time read and prepare data: 16.076836596999783
# Time writing label txt file: 0.09647749399300665
# Time read data file: 5.50230166799156
# Time read and prepare data: 22.09746044597705
# Time writing label txt file: 0.12270905097830109
# Time read data file: 5.37786891401629
# Time read and prepare data: 21.529875094012823
# Time writing label txt file: 0.12687355998787098
# Time read data file: 5.3360536549880635
# Time read and prepare data: 20.816208345990162
# Time writing label txt file: 0.12554209798690863
# Time read data file: 5.2632826440094505
# Time read and prepare data: 20.774105197982863
# Time writing label txt file: 0.12003641299088486
# Time read data file: 5.336423280998133
# Time read and prepare data: 21.28987156000221
# Time writing label txt file: 0.120450193004217
# Time read data file: 5.31841398999677
# Time read and prepare data: 20.4357673219929
# Time writing label txt file: 0.11971085099503398
# Time read data file: 1.5444028170022648
# Time read and prepare data: 5.711726697976701
# Time writing label txt file: 0.04161373898386955
# Time read data file: 13.66466198899434
# Time read and prepare data: 53.62868040401372
# Time writing label txt file: 0.3063037920219358
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/PhD/lib/python3.9/site-packages/plyfile.py:987, in _read_array(stream, dtype, n)
#     986     size = int(_np.dtype(dtype).itemsize * n)
# --> 987     return _np.frombuffer(stream.read(size), dtype)
#     988 except Exception:
#
# ValueError: buffer size must be a multiple of element size
#
# During handling of the above exception, another exception occurred:
#
# StopIteration                             Traceback (most recent call last)
# File ~/anaconda3/envs/PhD/lib/python3.9/site-packages/plyfile.py:739, in PlyElement._read_bin(self, stream, byte_order)
#     737 try:
#     738     self._data[prop.name][k] = \
# --> 739         prop._read_bin(stream, byte_order)
#     740 except StopIteration:
#
# File ~/anaconda3/envs/PhD/lib/python3.9/site-packages/plyfile.py:857, in PlyProperty._read_bin(self, stream, byte_order)
#     856 try:
# --> 857     return _read_array(stream, self.dtype(byte_order), 1)[0]
#     858 except IndexError:
#
# File ~/anaconda3/envs/PhD/lib/python3.9/site-packages/plyfile.py:989, in _read_array(stream, dtype, n)
#     988 except Exception:
# --> 989     raise StopIteration
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# PlyElementParseError                      Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       2 for filename in os.listdir(path):
#       3     GM_1 = Gaussian_Map()
# ----> 4     GM_1.load_ply(path + filename, quality_index)
#       5     GM_1.create_point_cloud()
#       6     GM_1.prep_orientate_mesh_pca ()
#
# File ~/Documents/PhD/segmentation/Wang et al. 2013/Gaussian_Map/gaussian_map.py:44, in Gaussian_Map.load_ply(self, filename, quality_index)
#      43 def load_ply(self, filename, quality_index):
# ---> 44     read_ply(filename, quality_index, self.Vertices, self.Edges, self.Faces, self.Links)
#      45     self.filename = os.path.splitext(filename)[0]
#
# File ~/Documents/PhD/segmentation/Wang et al. 2013/Gaussian_Map/adjustedMorse/LoadData/read_ply.py:29, in read_ply(filename, quality_index, vertices_dict, edges_dict, faces_dict, links_dict)
#      26 start_total_time = timeit.default_timer()
#      27 start_time = timeit.default_timer()
# ---> 29 rawdata = PlyData.read(filename)
#      31 end_time = timeit.default_timer() - start_time
#      32 print('Time read data file:', end_time)
#
# File ~/anaconda3/envs/PhD/lib/python3.9/site-packages/plyfile.py:397, in PlyData.read(stream, mmap)
#     395     data = PlyData._parse_header(stream)
#     396     for elt in data:
# --> 397         elt._read(stream, data.text, data.byte_order, mmap)
#     398 finally:
#     399     if must_close:
#
# File ~/anaconda3/envs/PhD/lib/python3.9/site-packages/plyfile.py:659, in PlyElement._read(self, stream, text, byte_order, mmap)
#     656     stream.seek(offset + self.count * dtype.itemsize)
#     657 else:
#     658     # A simple load is impossible.
# --> 659     self._read_bin(stream, byte_order)
#     661 self._check_sanity()
#
# File ~/anaconda3/envs/PhD/lib/python3.9/site-packages/plyfile.py:741, in PlyElement._read_bin(self, stream, byte_order)
#     738     self._data[prop.name][k] = \
#     739         prop._read_bin(stream, byte_order)
#     740 except StopIteration:
# --> 741     raise PlyElementParseError("early end-of-file",
#     742                                self, k, prop)
#
# PlyElementParseError: element 'vertex': row 317579: property 'quality': early end-of-file

# %%
GM_1 = Gaussian_Map()
GM_1.load_ply(filename, quality_index)
GM_1.create_point_cloud()
GM_1.ridgedetection()
# Out:
# Time read data file: 3.9043415329942945
# Time read and prepare data: 15.542269786004908
# Time writing label txt file: 0.04407372101559304
# Time writing label txt file: 0.04105701801017858
# 103.40513968467712

# %%
GM_1.prep_orientate_mesh_pca ()
GM_1.prep_orientate_mesh_Kmeans ()   
GM_1.save_exp_cloud ()
GM_1.export_exp_cloud_as_mesh ()
GM_1.recalculate_normals ()
# Out:
# Time writing label txt file: 0.08825414499733597

# %%
# self.point_cloud = [[value.x, value.y, value.z, value.quality,value.flags, 
#             value.red, value.green, value.blue, value.nx, value.ny, 
#             value.nz,value.phi, value.theta] for value in self.Vertices.values()]

faces = [list(value.indices) for value in GM_1.Faces.values()]
vertices = GM_1.point_cloud[:,:3]

faces = np.array(faces)

np.stack((faces [:,0],faces [:,1]), axis=1),np.stack((faces [:,1],faces [:,2]), axis=1),np.stack((faces [:,0],faces [:,2]), axis=1),
np.stack((faces [:,1],faces [:,0]), axis=1),np.stack((faces [:,2],faces [:,1]), axis=1),np.stack((faces [:,2],faces [:,0]), axis=1)

data = np.concatenate((np.stack((faces [:,0],faces [:,1]), axis=1),np.stack((faces [:,1],faces [:,2]), axis=1),
                       np.stack((faces [:,0],faces [:,2]), axis=1),np.stack((faces [:,1],faces [:,0]), axis=1),
                       np.stack((faces [:,2],faces [:,1]), axis=1),np.stack((faces [:,2],faces [:,0]), axis=1)), 
                       axis=0)
# transform to a DataFrame
df = pd.DataFrame(data)

# drop duplicated coonections
df = df.drop_duplicates()

# create a list of labels, append rows and transform to DataFrame
label_list =  []

for pid,label in enumerate(df_labels[0]):
    label_list.append(label.split(' '))

b = pd.DataFrame (label_list,columns=['a','b'])

# create dictionaries of a point and their adjacent points (df_dict), and of point and their adjacent labels
df_dict = {}
df_label_dict = {}

for key,v in enumerate(vertices):
    df_dict[key] = list(df[df[0] == key][1])

# finding ridge points by looking whether the points label and or adjacent labels are different. If yes, it's a ridge point.
ridge_key = []
ridge_key_infos = []
ridge_key_label = {}

df_label_dict = dict(zip(df_label.a, df_label.b))




for key,v in enumerate(vertices):
    value = []

    for v in df_dict[key]:
        value.append(df_label_dict [str(v)])

    value = value + [df_label_dict [str(key)]]
    unique_labels = '' 

    for n,i in enumerate (np.unique(value)):
        if n == 0:
            unique_labels = str(i) 
        else: 
            unique_labels = unique_labels + ',' +  str(i) 
    ridge_key_infos.append([key,unique_labels]) 


    if len(np.unique(value)) > 1:        
        ridge_key.append([key,2])
        
        print(set(value))
        ridge_key_label[key] = set((value))

    else:        
        ridge_key.append([key,1])
 
        


#################################################
# saving ridge points and the labels in different files.
ridge_dict = dict(ridge_key)
ridge_infos_dict = dict(ridge_key_infos)

jan.write_labels_txt_file (ridge_dict,path + name + '_ridge')  
jan.write_labels_txt_file (ridge_infos_dict,path + name + '_ridge_info')  
#pd.DataFrame([ridge_infos_dict]).to_csv(path + name + '_ridge_info',sep=',')
print(time.time())#-time_begin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 26>()
#      23 # create a list of labels, append rows and transform to DataFrame
#      24 label_list =  []
# ---> 26 for pid,label in enumerate(df_labels[0]):
#      27     label_list.append(label.split(' '))
#      29 b = pd.DataFrame (label_list,columns=['a','b'])
#
# NameError: name 'df_labels' is not defined

# %%
GM_1.point_cloud
# Out:
# array([[-12.93319988,  29.83130074,   4.01864004, ...,  -0.92102599,
#           0.26544333,   2.74150276],
#        [-12.83320045,  29.83130074,   3.99290991, ...,  -0.94960201,
#           0.170113  ,   2.82276011],
#        [-12.73320007,  29.83130074,   3.98423004, ...,  -0.95225799,
#           0.06552666,   2.83134508],
#        ...,
#        [-12.93319988,  27.43129921,   5.91021013, ...,   0.95344698,
#          -0.31051117,   0.30632913],
#        [-14.73320007,  32.03129959,   8.37312031, ...,   0.72953099,
#          -0.22854328,   0.75316036],
#        [-11.23320007,  34.63130188,  11.44989967, ...,   0.95358503,
#          -0.03567628,   0.30587101]])

# %%
# Out:
# [[-12.9332, 29.8313, 4.01864],
#  [-12.8332, 29.8313, 3.99291],
#  [-12.7332, 29.8313, 3.98423],
#  [-12.6332, 29.8313, 3.9837],
#  [-12.5332, 29.8313, 4.00157],
#  [-2.53322, 12.6313, 2.86074],
#  [-2.53322, 12.7313, 2.89217],
#  [-12.4332, 29.8313, 4.0053],
#  [-12.3332, 29.8313, 3.99978],
#  [-12.2332, 29.8313, 4.00944],
#  [-12.1332, 29.8313, 4.0237],
#  [-14.4369, 36.8649, 12.1861],
#  [-13.0406, 36.8938, 11.1928],
#  [-16.281, 8.33132, -1.07351],
#  [-16.2332, 8.38037, -1.07351],
#  [-16.1878, 8.43131, -1.07351],
#  [-2.53322, 12.8348, 2.92649],
#  [-16.1332, 8.51644, -1.07351],
#  [-12.1129, 29.8313, 4.02649],
#  [-12.0332, 29.8313, 4.03696],
#  [-11.9332, 29.8313, 4.04999],
#  [-11.8332, 29.8313, 4.04014],
#  [-11.7332, 29.8313, 4.04226],
#  [-12.1332, 10.6313, 1.98316],
#  [-12.0332, 10.6313, 2.00342],
#  [-11.6332, 29.8313, 4.04873],
#  [-11.9686, 10.6313, 2.02649],
#  [-10.601, 7.23131, -1.07351],
#  [-17.0102, 10.6313, 0.526491],
#  [-4.43322, 17.0313, 4.09459],
#  [-10.5942, 7.33131, -1.07351],
#  [-15.3332, 10.5313, 1.10125],
#  [-15.3332, 10.6229, 1.12649],
#  [-14.0744, 37.0555, 11.7554],
#  [-4.33322, 17.0313, 4.11692],
#  [-4.29598, 17.0313, 4.12649],
#  [-8.93322, 2.43131, 1.59091],
#  [-14.2335, 37.0977, 11.8267],
#  [-14.3999, 36.9692, 12.067],
#  [-8.93322, 2.63131, 1.6615],
#  [-2.97299, 17.0313, 4.02649],
#  [-2.93322, 17.0313, 3.99656],
#  [-3.07665, 17.0313, 4.12649],
#  [-3.03322, 17.0313, 4.08873],
#  [-15.9592, 10.6313, 0.926491],
#  [-15.9332, 10.6313, 0.933266],
#  [-15.8332, 10.6313, 0.964782],
#  [-15.7332, 10.6313, 1.00309],
#  [-2.8401, 17.0313, 3.92649],
#  [-15.675, 10.6313, 1.02649],
#  [-15.6332, 10.6313, 1.04168],
#  [-15.5332, 10.6313, 1.07275],
#  [-15.4332, 10.6313, 1.10088],
#  [-12.0706, 37.6728, 9.76419],
#  [-2.53322, 17.6623, 3.92649],
#  [-2.53322, 17.7313, 3.9446],
#  [-2.53322, 17.8313, 3.9964],
#  [-2.53322, 17.8766, 4.02649],
#  [-3.61494, 17.0313, 2.72649],
#  [-3.53322, 17.0313, 2.76613],
#  [-2.53322, 17.9313, 4.05419],
#  [-2.53322, 18.0313, 4.08636],
#  [-3.43322, 17.0313, 2.81153],
#  [-3.40586, 17.0313, 2.82649],
#  [-10.8368, 36.7287, 9.7909],
#  [-3.33322, 17.0313, 2.87044],
#  [-2.53322, 20.8638, 3.92649],
#  [-2.53322, 20.9313, 3.93908],
#  [-2.53322, 21.0313, 3.95608],
#  [-11.0476, 4.23131, 1.52649],
#  [-11.2512, 36.7427, 10.038],
#  [-10.9332, 4.23131, 1.56602],
#  [-2.53322, 21.1313, 3.96897],
#  [-15.3332, 21.6195, 3.32649],
#  [-15.3162, 9.83132, -1.07351],
#  [-3.23322, 17.0313, 2.9147],
#  [-3.20549, 17.0313, 2.92649],
#  [-2.53322, 21.2313, 3.98805],
#  [-15.3332, 21.6313, 3.33623],
#  [-2.53322, 21.3313, 4.01779],
#  [-15.2879, 9.93131, -1.07351],
#  [-2.53322, 21.3878, 4.02649],
#  [-15.2676, 10.0313, -1.07351],
#  [-2.53322, 21.4313, 4.03154],
#  [-15.3332, 21.7313, 3.37193],
#  [-15.2332, 10.11, -1.07351],
#  [-15.2198, 10.1313, -1.07351],
#  [-15.1592, 10.2313, -1.07351],
#  [-2.53322, 12.2392, 2.72649],
#  [-2.53322, 12.3313, 2.75721],
#  [-2.53322, 21.5313, 4.04682],
#  [-2.53322, 12.4313, 2.79241],
#  [-2.53322, 21.6313, 4.0677],
#  [-15.3332, 21.8313, 3.38665],
#  [-15.1332, 10.2785, -1.07351],
#  [-11.0739, 36.9208, 9.78281],
#  [-15.1031, 10.3313, -1.07351],
#  [-15.0332, 10.4163, -1.07351],
#  [-15.0195, 10.4313, -1.07351],
#  [-10.7916, 36.3476, 10.0751],
#  [-2.53322, 21.7313, 4.08846],
#  [-15.2126, 10.6313, -0.973509],
#  [-15.1332, 10.6313, -0.999564],
#  [-2.53322, 21.8313, 4.10402],
#  [-15.2332, 10.6313, -0.965548],
#  [-14.9561, 10.5313, -1.07351],
#  [-10.8332, 4.23131, 1.62187],
#  [-15.0332, 10.6313, -1.03025],
#  [-10.7703, 36.5739, 9.87259],
#  [-14.9332, 10.6016, -1.07351],
#  [-11.0287, 36.5297, 10.0882],
#  [-14.9189, 10.6313, -1.07351],
#  [-10.7332, 4.23131, 1.67097],
#  [-10.6332, 4.23131, 1.71627],
#  [-10.6134, 4.23131, 1.72649],
#  [-10.5332, 7.43652, -1.07351],
#  [-10.4332, 7.51245, -1.07351],
#  [-10.4146, 7.53131, -1.07351],
#  [-10.3646, 7.63131, -1.07351],
#  [-2.53322, 21.9179, 4.12649],
#  [-12.8666, 38.2728, 9.76906],
#  [-10.3332, 7.77522, -1.07351],
#  [-10.3201, 7.83131, -1.07351],
#  [-10.3156, 7.93131, -1.07351],
#  [-10.3142, 8.03131, -1.07351],
#  [-10.3039, 8.13132, -1.07351],
#  [-10.3053, 8.23131, -1.07351],
#  [-8.93322, 2.73131, 1.69427],
#  [-12.2774, 37.8604, 9.74956],
#  [-13.8676, 38.0871, 10.558],
#  [-17.9943, 10.6313, -0.173509],
#  [-17.9332, 10.6313, -0.253364],
#  [-18.0584, 10.6313, -0.073509],
#  [-18.0332, 10.6313, -0.124355],
#  [-17.9177, 10.6313, -0.273509],
#  [-15.3332, 21.9313, 3.42056],
#  [-15.3332, 21.9519, 3.42649],
#  [-10.2888, 8.33132, -1.07351],
#  [-15.3332, 22.0313, 3.44994],
#  [-10.2509, 8.43131, -1.07351],
#  [-13.7914, 37.9679, 10.6348],
#  [-12.8976, 38.081, 9.97508],
#  [-15.3332, 22.1313, 3.48443],
#  [-15.3332, 22.2313, 3.51934],
#  [-3.79415, 23.4313, 3.92649],
#  [-3.73322, 23.4313, 3.94816],
#  [-15.3332, 22.2633, 3.52649],
#  [-16.0906, 23.4313, 3.32649],
#  [-17.2399, 37.1399, 11.9849],
#  [-10.262, 8.73131, -1.07351],
#  [-17.0103, 37.3007, 11.8263],
#  [-16.0332, 23.4313, 3.43408],
#  [-15.9535, 23.4313, 3.52649],
#  [-8.93322, 9.79949, 2.32649],
#  [-17.3581, 37.0555, 12.0677],
#  [-15.3332, 19.5822, 2.72649],
#  [-15.3332, 19.6313, 2.7391],
#  [-10.2687, 9.03131, -1.07351],
#  [-15.3332, 19.7313, 2.77902],
#  [-8.93322, 9.83132, 2.32838],
#  [-15.3332, 19.8313, 2.81817],
#  [-3.63322, 23.4313, 3.97609],
#  [-12.9986, 38.0058, 10.0973],
#  [-14.7981, 37.8426, 10.7518],
#  [-8.93322, 30.7313, 4.53054],
#  [-3.51849, 23.4313, 4.02649],
#  [-8.93322, 30.8313, 4.57396],
#  [-9.93322, 10.6313, -0.976971],
#  [-9.89059, 10.6313, -0.973509],
#  [-9.73763, 10.6313, -0.973509],
#  [-9.73322, 10.6313, -0.98831],
#  [-9.83322, 10.6313, -0.972624],
#  [-9.6639, 10.6313, -0.973509],
#  [-9.63322, 10.6313, -0.959032],
#  [-9.53322, 10.6313, -0.902148],
#  [-9.49407, 10.6313, -0.873509],
#  [-8.0452, 10.6313, 2.42649],
#  [-7.94271, 10.6313, 2.42649],
#  [-14.2841, 38.0135, 9.78027],
#  [-13.2653, 37.6845, 10.5589],
#  [-7.83322, 10.6313, 2.40672],
#  [-7.73322, 10.6313, 2.40008],
#  [-15.3332, 10.7313, -0.902598],
#  [-15.3332, 10.8313, -0.874247],
#  [-12.4356, 37.698, 9.99947],
#  [-7.63322, 10.6313, 2.40921],
#  [-7.53322, 10.6313, 2.40887],
#  [-7.43322, 10.6313, 2.40897],
#  [-7.33322, 10.6313, 2.40991],
#  [-13.1926, 23.4313, 4.72649],
#  [-13.1332, 23.4313, 4.74844],
#  [-13.0332, 23.4313, 4.77971],
#  [-12.9332, 23.4313, 4.79828],
#  [-14.8548, 10.7313, -1.07351],
#  [-13.653, 37.7167, 10.7842],
#  [-14.7527, 10.8313, -1.07351],
#  [-14.7332, 10.8676, -1.07351],
#  [-16.1185, 23.4313, 2.92649],
#  [-16.0332, 23.4313, 2.89851],
#  [-15.9332, 23.4313, 2.87544],
#  [-14.6952, 10.9313, -1.07351],
#  [-14.6332, 10.9974, -1.07351],
#  [-14.5855, 11.0313, -1.07351],
#  [-15.8332, 23.4313, 2.86148],
#  [-15.7332, 23.4313, 2.83781],
#  [-15.6898, 23.4313, 2.82649],
#  [-15.6332, 23.4313, 2.81197],
#  [-15.5332, 23.4313, 2.78888],
#  [-15.4332, 23.4313, 2.75314],
#  [-15.3621, 23.4313, 2.72649],
#  [-14.5332, 11.0752, -1.07351],
#  [-12.8332, 23.4313, 4.82322],
#  [-12.8253, 23.4313, 4.82649],
#  [-12.7332, 23.4313, 4.8655],
#  [-12.6332, 23.4313, 4.88502],
#  [-12.5332, 23.4313, 4.90894],
#  [-14.4901, 11.1313, -1.07351],
#  [-12.1727, 37.5759, 9.91082],
#  [-12.4413, 23.4313, 4.92649],
#  [-14.4332, 11.264, -1.07351],
#  [-14.396, 11.3313, -1.07351],
#  [-14.3332, 11.407, -1.07351],
#  [-14.3082, 11.4313, -1.07351],
#  [-7.23322, 10.6313, 2.40488],
#  [-7.13322, 10.6313, 2.40238],
#  [-7.03322, 10.6313, 2.3931],
#  [-6.93322, 10.6313, 2.39525],
#  [-14.2332, 11.5094, -1.07351],
#  [-14.2197, 11.5313, -1.07351],
#  [-6.83322, 10.6313, 2.40047],
#  [-14.1944, 11.6313, -1.07351],
#  [-6.73322, 10.6313, 2.39201],
#  [-13.3846, 37.6144, 10.7081],
#  [-8.93322, 21.2313, 4.73497],
#  [-6.63322, 10.6313, 2.39781],
#  [-6.53322, 10.6313, 2.40557],
#  [-8.93322, 21.3313, 4.78785],
#  [-8.93322, 21.4313, 4.819],
#  [-17.1286, 17.0313, 1.12649],
#  [-17.0332, 17.0313, 1.10883],
#  [-16.9332, 17.0313, 1.0841],
#  [-14.1975, 11.7313, -1.07351],
#  [-14.1833, 11.8313, -1.07351],
#  [-15.2332, 35.844, 12.1131],
#  [-14.1332, 11.9583, -1.07351],
#  [-12.8938, 17.0313, 2.72649],
#  [-8.93322, 21.4555, 4.82649],
#  [-12.8332, 17.0313, 2.74812],
#  [-8.93322, 21.5313, 4.85284],
#  [-16.8332, 17.0313, 1.06578],
#  [-12.7332, 17.0313, 2.77055],
#  [-16.7332, 17.0313, 1.05176],
#  [-14.1058, 12.0313, -1.07351],
#  [-8.93322, 21.6313, 4.90824],
#  [-14.8047, 35.6963, 12.0532],
#  [-15.0564, 35.7285, 12.0401],
#  [-14.8598, 37.8102, 10.8267],
#  [-12.6332, 17.0313, 2.78744],
#  [-14.0332, 12.1561, -1.07351],
#  [-16.5332, 17.0313, 0.992389],
#  [-15.4332, 35.8564, 12.0985],
#  [-12.5332, 17.0313, 2.79733],
#  [-6.43322, 10.6313, 2.4068],
#  [-6.33322, 10.6313, 2.39805],
#  [-16.4332, 17.0313, 0.968544],
#  [-8.93322, 21.6638, 4.92649],
#  [-16.3332, 17.0313, 0.956677],
#  [-13.2921, 36.6719, 11.5455],
#  [-6.23322, 10.6313, 2.3959],
#  [-13.1973, 36.7345, 11.4265],
#  [-6.13322, 10.6313, 2.39672],
#  [-12.4332, 17.0313, 2.80398],
#  [-12.3332, 17.0313, 2.8079],
#  [-13.6619, 36.9052, 11.6021],
#  [-13.39, 36.8018, 11.5055],
#  [-6.03322, 10.6313, 2.3932],
#  [-12.1332, 17.0313, 2.84476],
#  [-5.93322, 10.6313, 2.39569],
#  [-5.83322, 10.6313, 2.40027],
#  [-5.73322, 10.6313, 2.40554],
#  [-13.9332, 12.2527, -1.07351],
#  [-13.9011, 12.3313, -1.07351],
#  [-13.8332, 12.4221, -1.07351],
#  [-13.8391, 37.0575, 11.582],
#  [-16.8049, 37.2676, 11.4237],
#  [-16.9573, 37.2528, 11.6683],
#  [-15.3332, 13.4572, -0.273509],
#  [-15.3332, 13.5313, -0.256376],
#  [-15.3332, 13.6313, -0.223723],
#  [-15.3332, 13.7313, -0.204038],
#  [-15.3332, 13.8313, -0.181156],
#  [-13.6555, 12.6313, -1.07351],
#  [-15.3332, 13.9259, -0.173509],
#  [-10.8834, 36.2818, 10.1957],
#  [-15.3332, 14.0313, -0.156813],
#  [-13.6332, 12.6518, -1.07351],
#  [-13.0774, 37.9205, 10.216],
#  [-13.5332, 12.7577, -1.07351],
#  [-15.3332, 14.1313, -0.134697],
#  [-13.4942, 12.8313, -1.07351],
#  [-15.3332, 14.2313, -0.120589],
#  [-13.4332, 12.9195, -1.07351],
#  [-13.7662, 38.2376, 10.1917],
#  [-15.3332, 14.3313, -0.0983358],
#  [-14.0132, 38.1536, 10.4265],
#  [-14.0132, 38.1684, 10.2265],
#  [-15.3332, 14.4422, -0.073509],
#  [-14.4756, 37.9941, 10.4265],
#  [-5.63322, 10.6313, 2.40763],
#  [-5.53322, 10.6313, 2.40036],
#  [-13.264, 13.1313, -1.07351],
#  [-13.2332, 13.1658, -1.07351],
#  [-13.1835, 13.2313, -1.07351],
#  [-5.43322, 10.6313, 2.39041],
#  [-5.33322, 10.6313, 2.39355],
#  [-13.1332, 13.2997, -1.07351],
#  [-13.1138, 13.3313, -1.07351],
#  [-13.0332, 13.4313, -1.07351],
#  [-14.4665, 37.9973, 10.2098],
#  [-5.23322, 10.6313, 2.39038],
#  [-5.13322, 10.6313, 2.38436],
#  [-5.03322, 10.6313, 2.3819],
#  [-4.93322, 10.6313, 2.38422],
#  [-12.6836, 37.4559, 10.3733],
#  [-12.5911, 37.5426, 10.2351],
#  [-12.7638, 37.3772, 10.4992],
#  [-12.9593, 13.6313, -1.07351],
#  [-12.9332, 13.6523, -1.07351],
#  [-15.3332, 15.879, 0.326491],
#  [-15.3332, 15.9313, 0.339556],
#  [-15.3332, 16.0313, 0.367206],
#  [-12.868, 13.7313, -1.07351],
#  [-12.8332, 13.7751, -1.07351],
#  [-12.7815, 13.8313, -1.07351],
#  [-4.83322, 10.6313, 2.39008],
#  [-4.73322, 10.6313, 2.38669],
#  [-15.3332, 16.1313, 0.393704],
#  [-4.63322, 10.6313, 2.38143],
#  [-15.3332, 16.2154, 0.426491],
#  [-4.53322, 10.6313, 2.37712],
#  [-13.0815, 37.7176, 10.4123],
#  [-15.3332, 16.3313, 0.471653],
#  [-4.43322, 10.6313, 2.37227],
#  [-15.3332, 16.4313, 0.489603],
#  [-4.33322, 10.6313, 2.37503],
#  [-4.23322, 10.6313, 2.38472],
#  [-15.3332, 16.5313, 0.522539],
#  [-10.979, 36.9907, 9.66585],
#  [-4.13322, 10.6313, 2.38645],
#  [-10.2561, 10.7313, -1.07351],
#  [-10.2332, 10.6494, -1.07351],
#  [-15.7332, 37.2313, 12.5302],
#  [-6.30271, 4.23131, 0.926491],
#  [-15.9332, 37.2313, 12.6011],
#  [-6.23322, 4.23131, 0.976148],
#  [-6.15465, 4.23131, 1.02649],
#  [-6.13322, 4.23131, 1.04066],
#  [-10.2332, 10.9684, -1.07351],
#  [-10.2313, 11.0313, -1.07351],
#  [-15.3332, 26.1713, 4.72649],
#  [-15.3332, 26.2313, 4.74595],
#  [-6.03322, 4.23131, 1.10555],
#  [-5.99453, 4.23131, 1.12649],
#  [-15.3332, 26.3313, 4.7906],
#  [-15.3332, 26.3939, 4.82649],
#  [-15.3332, 26.4313, 4.84483],
#  [-15.3332, 26.5313, 4.86782],
#  [-15.3332, 26.6313, 4.89027],
#  [-4.03322, 10.6313, 2.39613],
#  [-10.2306, 11.1313, -1.07351],
#  [-3.93322, 10.6313, 2.40299],
#  [-16.1332, 37.2313, 12.6231],
#  [-10.2332, 11.1377, -1.07351],
#  [-8.93322, 27.8085, 3.32649],
#  [-8.93322, 27.8313, 3.33441],
#  [-3.83322, 10.6313, 2.39171],
#  [-3.73322, 10.6313, 2.38418],
#  [-16.3332, 37.2313, 12.6152],
#  [-8.93322, 11.4313, 2.43338],
#  [-10.5607, 12.6313, -1.07351],
#  [-10.5332, 12.5985, -1.07351],
#  [-10.6252, 12.7313, -1.07351],
#  [-10.6573, 12.8313, -1.07351],
#  [-10.6332, 12.7549, -1.07351],
#  [-17.1513, 29.8313, 4.82649],
#  [-17.1332, 29.8313, 4.81442],
#  [-10.7697, 13.0313, -1.07351],
#  [-17.2156, 29.8313, 4.92649],
#  [-10.7332, 12.9769, -1.07351],
#  [-10.7053, 12.9313, -1.07351],
#  [-17.0332, 29.8313, 4.77253],
#  [-16.9332, 29.8313, 4.73785],
#  [-2.53322, 9.04949, 2.12649],
#  [-2.53322, 9.13132, 2.09883],
#  [-2.53322, 9.23131, 2.10152],
#  [-10.8059, 13.1313, -1.07351],
#  [-15.3332, 3.06128, -1.67351],
#  [-15.3332, 3.13131, -1.70406],
#  [-15.3332, 3.23131, -1.7082],
#  [-16.8151, 37.2313, 12.7265],
#  [-10.8332, 13.2203, -1.07351],
#  [-15.3332, 3.33131, -1.70492],
#  [-13.5332, 37.2313, 11.1948],
#  [-15.3332, 3.43131, -1.67599],
#  [-2.53322, 9.39751, 2.12649],
#  [-15.5332, 37.0313, 12.5536],
#  [-10.8724, 13.3313, -1.07351],
#  [-15.3332, 3.76101, -1.67351],
#  [-15.3332, 3.83131, -1.67972],
#  [-10.9309, 13.4313, -1.07351],
#  [-15.3332, 23.454, 2.72649],
#  [-15.3332, 23.5313, 2.75608],
#  [-15.3332, 23.6313, 2.78839],
#  [-15.3332, 3.93131, -1.68441],
#  [-15.3332, 4.03131, -1.69487],
#  [-15.3332, 4.13131, -1.68965],
#  [-13.5332, 37.4313, 10.9903],
#  [-15.3332, 4.23131, -1.67699],
#  [-11.0016, 13.5313, -1.07351],
#  [-13.6725, 10.6313, 1.62649],
#  [-10.9332, 13.4348, -1.07351],
#  [-13.5332, 37.2969, 11.1265],
#  [-11.0332, 13.6136, -1.07351],
#  [-13.6332, 10.6313, 1.64603],
#  [-13.5332, 10.6313, 1.68302],
#  [-11.1547, 13.8313, -1.07351],
#  [-11.1332, 13.7952, -1.07351],
#  [-15.3332, 23.7313, 2.81925],
#  [-15.3332, 23.7551, 2.82649],
#  [-13.4332, 10.6313, 1.6985],
#  [-11.0906, 13.7313, -1.07351],
#  [-13.3332, 10.6313, 1.71607],
#  [-15.3332, 23.8313, 2.84729],
#  [-8.93322, 28.3313, 3.50271],
#  [-8.93322, 28.3838, 3.52649],
#  [-16.89, 29.8313, 4.72649],
#  [-15.3332, 23.9313, 2.87031],
#  [-16.7672, 29.8313, 4.72649],
#  [-16.7332, 29.8313, 4.73488],
#  [-13.276, 10.6313, 1.72649],
#  [-15.3332, 24.0313, 2.90312],
#  [-16.6332, 29.8313, 4.74392],
#  [-16.5332, 29.8313, 4.74149],
#  [-15.3332, 24.0978, 2.92649],
#  [-16.4332, 29.8313, 4.73608],
#  [-16.376, 29.8313, 4.72649],
#  [-8.83322, 17.0313, 3.35357],
#  [-8.73322, 17.0313, 3.36598],
#  [-10.463, 12.3313, -1.07351],
#  [-10.4332, 12.2704, -1.07351],
#  [-10.4893, 12.4313, -1.07351],
#  [-8.63322, 17.0313, 3.38543],
#  [-8.53322, 17.0313, 3.40434],
#  [-10.5057, 12.5313, -1.07351],
#  [-12.8191, 17.0313, -0.073509],
#  [-12.7332, 17.0313, -0.107099],
#  [-8.93322, 11.5313, 2.43954],
#  [-13.7206, 37.4313, 11.1265],
#  [-13.3332, 37.2313, 11.0574],
#  [-12.6332, 17.0313, -0.146578],
#  [-8.93322, 11.6313, 2.46395],
#  [-12.5332, 17.0313, -0.155089],
#  [-3.03322, 10.6313, 1.98919],
#  [-2.96755, 10.6313, 2.02649],
#  [-8.4522, 17.0313, 3.42649],
#  [-2.93322, 10.6313, 2.04606],
#  [-8.43322, 17.0313, 3.43286],
#  [-8.93322, 11.7313, 2.4842],
#  [-8.33322, 17.0313, 3.45787],
#  [-12.4551, 17.0313, -0.173509],
#  [-12.4332, 17.0313, -0.180701],
#  [-8.93322, 11.8313, 2.47852],
#  [-12.3332, 17.0313, -0.219603],
#  [-8.23322, 17.0313, 3.46323],
#  [-8.13322, 17.0313, 3.48489],
#  [-12.2332, 17.0313, -0.251547],
#  [-12.1736, 17.0313, -0.273509],
#  [-15.3332, 12.6594, 1.52649],
#  [-15.3332, 12.7313, 1.53615],
#  [-15.3332, 12.8313, 1.55371],
#  [-2.83322, 10.6313, 2.09527],
#  [-2.76561, 10.6313, 2.12649],
#  [-15.3332, 12.9313, 1.56485],
#  [-15.3332, 13.0313, 1.59035],
#  [-8.93322, 14.1136, -0.273509],
#  [-13.3332, 37.164, 11.1265],
#  [-8.93322, 14.2313, -0.243722],
#  [-7.6649, 4.23131, 0.326491],
#  [-7.63322, 4.23131, 0.346814],
#  [-7.53322, 4.23131, 0.393457],
#  [-8.03322, 17.0313, 3.50122],
#  [-8.93322, 14.3313, -0.229223],
#  [-13.4342, 37.2313, 11.1265],
#  [-7.93322, 17.0313, 3.49383],
#  [-8.93322, 29.2813, 3.92649],
#  [-8.93322, 14.4313, -0.217178],
#  [-7.43322, 4.23131, 0.426786],
#  [-8.93322, 29.3313, 3.95317],
#  [-7.83322, 17.0313, 3.51351],
#  [-7.33322, 4.23131, 0.45971],
#  [-15.3332, 13.1313, 1.61111],
#  [-7.80472, 17.0313, 3.52649],
#  [-15.3332, 13.2313, 1.61983],
#  [-8.93322, 11.9313, 2.46497],
#  [-8.93322, 29.4313, 3.98729],
#  [-8.93322, 12.0313, 2.48323],
#  [-8.93322, 14.5313, -0.194329],
#  [-15.5332, 36.8313, 12.568],
#  [-7.23322, 4.23131, 0.497363],
#  ...]

# %%
def ridgedetection (self):
    
    time_begin = time.time()
    
    # define variables
    filename = self.filename + ".ply" # 3D file of the model
    labelname = self.filename  + ".txt" #  label of the segmentation
    df_labels = pd.read_csv(labelname,skiprows=5,header=None) # import txt segmentation 
    
    # importing 3D model
#     ms = pymeshlab.MeshSet()
#     ms.load_new_mesh(filename)
    
    # separate faces and point cloud
    faces = np.array([list(self.Faces[i].indices) for i in self.Faces])
    vertices = [[value.x, value.y, value.z] for value in self.Vertices.values()]
    
    #redefine faces as ndarray
#     faces = np.array(faces)
    vertices = self.point_cloud[:,:3]
    # create a ndarray of all individual edges between points bidirectional
    np.stack((faces [:,0],faces [:,1]), axis=1),np.stack((faces [:,1],faces [:,2]), axis=1),np.stack((faces [:,0],faces [:,2]), axis=1),
    np.stack((faces [:,1],faces [:,0]), axis=1),np.stack((faces [:,2],faces [:,1]), axis=1),np.stack((faces [:,2],faces [:,0]), axis=1)

    data = np.concatenate((np.stack((faces [:,0],faces [:,1]), axis=1),np.stack((faces [:,1],faces [:,2]), axis=1),
                           np.stack((faces [:,0],faces [:,2]), axis=1),np.stack((faces [:,1],faces [:,0]), axis=1),
                           np.stack((faces [:,2],faces [:,1]), axis=1),np.stack((faces [:,2],faces [:,0]), axis=1)), 
                           axis=0)
    # transform to a DataFrame
    df = pd.DataFrame(data)

    # drop duplicated coonections
    df = df.drop_duplicates()
    
    # create a list of labels, append rows and transform to DataFrame
    label_list =  []

    for pid,label in enumerate(df_labels[0]):
        label_list.append(label.split(' '))

    df_label = pd.DataFrame (label_list,columns=['a','b'])
    
    # create dictionaries of a point and their adjacent points (df_dict), and of point and their adjacent labels
    df_dict = {}
    df_label_dict = {}

    for key,v in enumerate(vertices):
        df_dict[key] = list(df[df[0] == key][1])
    
    # finding ridge points by looking whether the points label and or adjacent labels are different. If yes, it's a ridge point.
    ridge_key = []
    ridge_key_infos = []

    df_label_dict = dict(zip(df_label.a, df_label.b))

    for key,v in enumerate(vertices):
        value = []

        for v in df_dict[key]:
            value.append(df_label_dict [str(v)])

        value = value + [df_label_dict [str(key)]]
        unique_labels = '' 
        
        for n,i in enumerate (np.unique(value)):
            if n == 0:
                unique_labels = str(i) 
            else: 
                unique_labels = unique_labels + ',' +  str(i) 
        ridge_key_infos.append([key,unique_labels]) 
        
        
        if len(np.unique(value)) > 1:        
            ridge_key.append([key,2])
            
        else:        
            ridge_key.append([key,1])
       
   
    #################################################
    # saving ridge points and the labels in different files.
    ridge_dict = dict(ridge_key)
    ridge_infos_dict = dict(ridge_key_infos)
    
    jan.write_labels_txt_file (ridge_dict,path + name + '_ridge')  
    jan.write_labels_txt_file (ridge_infos_dict,path + name + '_ridge_info')  
    #pd.DataFrame([ridge_infos_dict]).to_csv(path + name + '_ridge_info',sep=',')
    print(time.time()-time_begin)
    
ridgedetection(path,name)
# Out:
# [[-12.933199882507324, 29.831300735473633, 4.018640041351318], [-12.833200454711914, 29.831300735473633, 3.9929099082946777], [-12.733200073242188, 29.831300735473633, 3.9842300415039062], [-12.633199691772461, 29.831300735473633, 3.9837000370025635], [-12.53320026397705, 29.831300735473633, 4.001570224761963], [-2.533220052719116, 12.63129997253418, 2.8607399463653564], [-2.533220052719116, 12.731300354003906, 2.892169952392578], [-12.433199882507324, 29.831300735473633, 4.005300045013428], [-12.333200454711914, 29.831300735473633, 3.9997799396514893], [-12.233200073242188, 29.831300735473633, 4.009439945220947], [-12.133199691772461, 29.831300735473633, 4.02