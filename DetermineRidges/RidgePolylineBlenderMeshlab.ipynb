# %%
import os,sys

currentdir = os.getcwd()
parentdir = os.path.dirname(currentdir)
pparentdir = os.path.dirname(parentdir)
sys.path.insert(0, parentdir) 
sys.path.insert(0, ''.join([pparentdir,'/minions'])) 
sys.path.insert(0, ''.join([parentdir,'/Functions','/Procedures'])) 

from util import *

# from Functions.Procedures.LabbelledMeshProcedures import update_label_procedure
from Functions.main import procedures,transform_labelledmesh_procedures

# from LabelMinions import color_to_binary_label,color_to_label

# %%
# path = '/home/linsel/Documents/PhD/Data/Cologne' 
# # color = ''
# # ending = '.ply'

# r,n,v = 1.00,4,256

# workflow = {    0:{ 'name':'MEAS',
#                     'method':'',
#                     'stage':'',                    
#                     'parameters':'',
#                     'processed':'',
#                     'metadata':['']},  

#                 1:{ 'name':'GMCF',
#                     'method':'gigamesh-clean',
#                     'stage':'preprocessing',                    
#                     'parameters':'',
#                     'derive_from': 0,
#                     'processed':'_GMCF',
#                     'metadata':['mesh_polish']},

#                 2:{ 'name':'MSII',
#                     'method':'gigamesh-featurevectors',
#                     'stage':'preprocessing',                  
#                     'parameters':'-r {} -n {} -l {}'.format(r,n,v),
#                     'derive_from': 1,
#                     'processed':'_r{}_n{}_v{}'.format(r,n,v),
#                     'metadata':['info','normal','surface','volume']}

#                     }


# folder = 'Cologne_2022_ANNO'

# workflow_path = "/".join([path,folder,''.join(['workflow','.json'])])


# # workflow import 

# with open(workflow_path) as handle:
#     imp_workflow = json.loads(handle.read())

# %% [markdown]
# # Color to Label

# %%
# # method = ''.join([pparentdir,'/minions/MorseMeshMinions/color_to_labels.py'])
# # method = ''.join([pparentdir,'/minions/MorseMeshMinions/color_to_labels.py'])
# # method = ''.join([pparentdir,'/minions/ColorMinions/color_to_binary_label.py'])

# # path = '/home/linsel/Documents/PhD/Data/Fumane/annotated/blender/temp/'
# path = '/home/linsel/Documents/PhD/Data/Graphs/Cologne_test_knapping_202307_02_MeshLab/Nc/'
# path = '/home/linsel/Documents/PhD/Data/Blender_Workflow/BLEND/Rebecca/'
# # path = '/home/linsel/Documents/PhD/Data/Delpiano_et_al_2017_ANNO/Delpiano_et_al_2017_02_ANNO/'
# path ='/home/linsel/Documents/PhD/Data/Cologne/Cologne_Interns_2024/Cologne_Interns_2024_01_ANNO/'
# path ='/home/linsel/Downloads/TK/'
# path ='/home/linsel/Documents/PhD/Data/Cologne/Cologne_Interns_2024/n/'

# ind = '1241.2'#'10350'#'TK_008'#'1401'#'1241.2'

# path = '/home/linsel/Documents/PhD/Data/Robertinum/{}/'.format(id)

# path = '/home/linsel/Documents/PhD/Data/Blender_Workflow/blender/'

# path = '/home/linsel/Downloads/Falcucci-Peresani_2022-cores/Falcucci-Peresani_2022-cores_01_GMCF_c_Blender/'

# # id = 'TK_005'
# preprocessed = '_GMOCF_c'
# preprocessed = '_GMCF_c'
# # preprocessed = '_c_GMCF'
# color = ''#'_c'
# ending = '.ply'
# tresh = 50
# class_type = 'transform_labelledmesh'
# method ='color_to_scar_labels'
# ridge_label = 1


# # kwargs = {'path': path,
# #         'id': ind,
# #         'preprocessed': preprocessed,
# #         'color': color,
# #         'class': class_type,
# #         'method': method,
# #         'ending': ending,
# #         'tresh': tresh,
# #         'ridge_label' :ridge_label        
# #         }

# # One 3D model 

# # procedures(**kwargs)

# # multiple 3D models

# for filename in os.listdir(path):
#     print(filename)

#     if filename.endswith(''.join([preprocessed,color,ending])):  

#         file = filename.split('_')[0]

#         kwargs = {'path': path,
#                 'id': file,
#                 'class': class_type,
#                 'preprocessed':preprocessed,
#                 'color': color,
#                 'method': method,
#                 'ending': ending,
#                 'tresh': tresh,
#                 'ridge_label' :ridge_label
#                 }

#         procedures(**kwargs)

# %%
# ind,preprocessed,ext,labelname = '1241.2','_GMOCF_c3','_nodes.csv','_GMOCF_c2_gt_labels'

# path = "/home/linsel/Documents/PhD/Data/Robertinum/"
# folder = "1241.2"

# subfolder_path = '/'.join([path,folder,''])

# color = ''
# ending = '.ply'
# tresh = 30
# class_type = 'transform_labelledmesh'

# method ='color_to_scar_labels'
# ridge_label = 1

# kwargs = {  'path': subfolder_path,        
#             'id': ind,
#             'class': class_type,
#             'preprocessed':preprocessed,
#             'color': color,
#             'method': method,
#             'ending': ending,
#             'tresh': tresh,
#             'ridge_label': ridge_label
#             }


# procedures(**kwargs)

# %%
# import trimesh 

# tr = trimesh.load_mesh(''.join([subfolder_path, ind, preprocessed, ending ]))

# tr.export (''.join([subfolder_path, ind, preprocessed, '2', ending ]))

# %%
# folder = 'Cologne_test_knapping_202307'

# ind,preprocessed,ext,labelname = 'TK-005','_GMOCF_r1.00_n4_v256.volume','_nodes.csv','_GMOCF_r1.00_n4_v256.volume_scar-labels'

# path = "/home/linsel/Documents/PhD/Data/Cologne" 
# folder = 'Cologne_test_knapping_202307'

# subfolder_path = '/'.join([path,folder,'Cologne_test_knapping_202307_02_ANNO',''])

# id = 'TK_005'
# preprocessed = '_GMCF_c'
# color = ''#'_c'
# ending = '.ply'
# tresh = 500
# class_type = 'transform_labelledmesh'
# # method ='color_to_scar_labels'
# method ='color_to_scar_labels'
# ridge_label = 1

# kwargs = {  'path': subfolder_path,        
#             'id': ind,
#             'class': class_type,
#             'preprocessed':preprocessed,
#             'color': color,
#             'method': method,
#             'ending': ending,
#             'tresh': tresh,
#             'ridge_label': ridge_label
#             }


# procedures(**kwargs)

# %% [markdown]
# ## Process of Simplifying 3D Labels

# %%
exp_path = 'exp_path/'
# id = 'MoST_3411'
# preprocessed = '_c'#_GMCF'#_GMOCF'
labelname = '_c_gt_labels'

# # path = '/home/linsel/Documents/PhD/Data/stonetoolsmuseum/MoST_3411/'
# path = '/home/linsel/Documents/PhD/Data/Fumane/Blender/BLEND/Tin/'
# path = '/home/linsel/Documents/PhD/Data/Graphs/Cologne_test_knapping_202307_02_MeshLab/c/'
# path = '/home/linsel/Documents/PhD/Data/Graphs/Cologne_test_knapping_202307_02_MeshLab/Nc/'
ending = '.txt'

for filename in os.listdir(path):
    
    if filename.endswith(''.join([labelname,'ply'])):  
        
        file = '_'.join(filename.split('_')[0])

        kwargs = {'path':path,
                'id':file,
                'preprocessed':preprocessed,
                'labelname':labelname,
                'exp_path':exp_path
                }
        try:
                # TLM1 = transform_labelledmesh_procedures('scar_to_ridge_labels_binary',**kwargs)

                color_to_binary_label(**kwargs)

                binary_label = ''.join([kwargs['preprocessed'],kwargs['color'],'_binary_labels'])

                kwargs.update({'labelname':binary_label})

                TLM2 = procedures('transform_labelledmesh','scar_to_ridge_labels_CC',**kwargs)
                ridge_labelname = '_ridge-labels-CC'

                kwargs = {'path':path,
                        'id':file,
                        'preprocessed':preprocessed,
                        'labelname':ridge_labelname,
                        'exp_path':exp_path
                        }

                # TLM3 = transform_labelledmesh_procedures('ridge_CC_to_scar_labels',**kwargs)
                TLM4 = procedures('transform_labelledmesh','color_to_scar_labels',**kwargs)
                
        except:
             print(filename)

# %% [markdown]
# ## Evaluation

# %%
# def check_fitting(label): 
#     return sum([1 for n in np.array(list(label.values())) - np.array(list(label.values())) if n != 0])/len(label.values())

# check_fitting (TLM1.dict_label)
