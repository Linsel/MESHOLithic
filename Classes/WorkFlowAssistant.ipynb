# %%
import os,sys
from functools import reduce

currentdir = os.getcwd()
parentdir = os.path.dirname(currentdir)
gparentdir = os.path.dirname(parentdir)
ggparentdir = os.path.dirname(gparentdir)

sys.path.insert(0, '/'.join([gparentdir,'prototyping'])) 
sys.path.insert(0, '/'.join([parentdir])) 
sys.path.insert(0, '/'.join([gparentdir,'minions'])) 
sys.path.insert(0, '/'.join([gparentdir])) 
sys.path.insert(0, '/'.join([parentdir,'Functions','Procedures'])) 

from GigaMeshMinions import command_line_GigaMesh
from Functions.WorkFlow import run_workflow

import json

# %%
# json_dict = {1:{'name': 'GMAO', 'class': 'GigaMesh', 'stage': 1, 'method': '', 'parameters': '', 'add_labels' : False, 'variables': '', 'processed': '_GMAO', 'metadata': ['']},
# 2:{'name': 'GMCF', 'class': '', 'stage': 2, 'method': '', 'variables': {}, 'parameters': '-m "original, lithic"', 'add_labels' : False, 'processed': '_GMCF', 'metadata': ['mesh_polish']},
# 3:{'name': 'MSII', 'class': '', 'stage': 3, 'method': '', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
# 4:{"name": "CO_concavity", "class": "MSII_CO", "method": "CO_concavity", "stage": 4, "parameters": "", "variables": {"graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16, "preprocessed":"","labelname": "_scar-labels"}, "processed": "", "labelname": "_GMCF_c_scar-labels", "metadata": [""]}}


# json_dicts = {1: {1:{'name': 'GMAO', 'stage': 1, 'class': 'GigaMesh', 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
# 2:{'name': 'GMCF', 'stage': 2, 'class': 'GigaMesh', 'method': 'gigamesh-clean', 'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
# 3:{'name': 'MSII', 'stage': 3, 'class': '', 'method': '', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
# 4:{'name':'MSII_1D','stage':4,'class':'MSII_CO','method':'MSII', 'parameters':'', 'add_labels' : True, 'variables':{'labelname':'_scar-labels', "graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''}}}}

# json_dicts = {0:{1:{'name': 'GMAO', "derived_from": "MEAS", 'class': 'GigaMesh', 'stage': 1, 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
#                  2:{'name': 'ANNO', 'stage': 2, 'class': '', 'method': '', 'parameters': {'preprocessed': '_GMFC'}, 'variables': [''], 'preprocessed': '_GMFC', 'metadata': ['']},
#                  3:{'name':'LABL','stage':3, 'class': 'transform_labelledmesh','method': 'rindge_color_to_scar_labels','parameters':'','variables':{'tresh': 20,'ending': '.ply','preprocessed': ''},'metadata':['_CC-labels','_scar-labels']}}}



# json_dicts.update ({1:{1:{'name': 'GMAO', "derived_from": "MEAS", 'class': 'GigaMesh', 'stage': 1, 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
#                        2:{'name': 'GMCF', 'stage': 2, 'class': 'GigaMesh', 'method': 'gigamesh-clean', 'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
#                        3:{'name': 'MSII', 'stage': 3, 'class': 'GigaMesh', 'method': 'gigamesh-featurevectors', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']}}})

json_dicts = {1: {3:{'name': 'MSII', 'stage': 1, 'class': 'GigaMesh', 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']}}}


# json_dicts.update ({1: {1:{'name': 'GMAO', 'stage': 1, 'class': 'GigaMesh', 'method': '',                 'parameters': '',                    'variables': {}, 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
#                   2:{'name': 'GMCF', 'stage': 2, 'class': 'GigaMesh', 'method': 'gigamesh-clean',   'parameters': '',                    'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
#                   3:{'name': 'MSII', 'stage': 3, 'class': '',         'method': '',                 'parameters': '-r 1.00 -n 4 -l 256', 'variables': {'r': 1.0, 'n': 4, 'v': 256},  'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
#                   4:{'name': 'MSII-1D','stage':4,'class':'CO-MSII',    'method': 'MSII',            'parameters':'',                     'variables':{'labelname':'_scar-labels', "graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''}, 'add_labels' : True, 'add_links': False, "metadata": [""]}}})


# quality
json_dicts.update ({3:{1:{'name': 'GMAO',        "derived_from": "MEAS", 'class': 'GigaMesh', 'method': '',                'stage': 1, 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
                      2:{'name': 'ANNO',         "derived_from": "GMAO", 'class': 'GigaMesh', 'method': 'gigamesh-clean',  'stage': 2, 'add_labels' : False, 'variables': {}, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
                      3:{'name': 'MSII',         "derived_from": "GMCF", 'class': '',         'method': '',                'stage': 3, 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
                      4:{"name": "CO-Concavity", "derived_from": 'MSII', "class": "CO-MSII",  "method": "CO_concavity",    "stage": 4, "parameters": "", 'add_labels' : True, 'add_links': False, "variables": {"labelname": "_scar-labels","graphname": "max", "diameter": 1, "parameters": ["quality"], "n_rad": 4, "preprocessed":""}, "processed": "", "labelname": "_scar-labels","metadata": []}}})



# normals 
json_dicts = {3:{1:{'name': 'GMAO',        "derived_from": "MEAS", 'class': 'GigaMesh', 'method': '',                'stage': 1, 'parameters': '', 'variables': '', 'add_labels' : False, 'add_links' : False, 'processed': '_GMAO', 'metadata': ['']},
                 2:{'name': 'GMCF', 'stage': 2, 'class': 'GigaMesh', 'method': 'gigamesh-clean', 'variables': {}, 'add_labels' : False, 'add_links' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
                 3:{'name': 'MSII', 'stage': 3, 'class': 'GigaMesh', 'method': 'gigamesh-featurevectors', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'add_links' : False,'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']}}}
                #  4:{"name": "CO-Normals", "derived_from": 'MSII', "class": "CO-MSII",  "method": "CO_concavity",    "stage": 4, "parameters": "", 'add_labels' : True, 'add_links': False, "variables": {"labelname": "_scar-labels","graphname": "max", "diameter": 1, "parameters": ["nx","ny","nz"], "n_rad": 4, "preprocessed":""}, "processed": "", "labelname": "_scar-labels","metadata": []}},
                #  5:{"name": "CO-Concavity", "derived_from": 'MSII', "class": "CO-MSII",  "method": "CO_concavity",    "stage": 4, "parameters": "", 'add_labels' : True, 'add_links': False, "variables": {"labelname": "_scar-labels","graphname": "max", "diameter": 1, "parameters": ["quality"], "n_rad": 4, "preprocessed":""}, "processed": "", "labelname": "_scar-labels","metadata": []}}

json_dicts = {3:{3:{'name': 'MSII', 'stage': 3, 'class': 'GigaMesh', 'method': '', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'add_links' : False,'processed': '_r1.00_n4_v256.volume', 'metadata': []},
                 4:{"name": "CO-Normals", "derived_from": 'MSII', "class": "CO-MSII",  "method": "CO_concavity",    "stage": 4, "parameters": "", 'add_labels' : True, 'add_links': False, "variables": {"labelname": "_scar-labels","graphname": "max", "max_rad": 1, "parameters": ["nx","ny","nz"], "n_rad": 4, "preprocessed":""}, "processed": "", "linkname": "_links.csv", "labelname": "_scar-labels.txt","metadata": []},
                 5:{"name": "CO-Concavity", "derived_from": 'MSII', "class": "CO-MSII",  "method": "CO_concavity",    "stage": 4, "parameters": "", 'add_labels' : True, 'add_links': False, "variables": {"labelname": "_scar-labels","graphname": "max", "max_rad": 1, "parameters": ["quality"], "n_rad": 4, "preprocessed":""}, "processed": "", "linkname": "_links.csv","labelname": "_scar-labels.txt","metadata": []}}}




# json_dicts = {4:{1:{'name': 'GMAO', "derived_from": "MEAS", 'class': 'GigaMesh', 'method': '', 'stage': 1, 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
#                        2:{'name': 'GMCF', "derived_from": "GMAO", 'class': 'GigaMesh', 'method': 'gigamesh-clean', 'stage': 2, 'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
#                        3:{'name': 'MSII', "derived_from": "GMCF", 'cla005ss': '', 'method': '', 'stage': 3, 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
#                        4:{'name': 'CO-MSII-fv', "derived_from": "MSII",'class':'CO-MSII', 'method':'MSII_feature_vector', 'stage':4, 'parameters':'', 'add_labels' : True, 'add_links': True, 'variables':{'labelname':'_scar-labels', "graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''},'metadata': []}}}

# json_dicts = {4:{1:{'name': 'GMAO', "derived_from": "MEAS", 'class': 'GigaMesh', 'stage': 1, 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
#                       2:{'name': 'GMCF', "derived_from": "GMAO", 'class': 'GigaMesh', 'stage': 2, 'method': 'gigamesh-clean', 'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
#                       3:{'name': 'MSII', "derived_from": "GMCF", 'class': '', 'stage': 3, 'method': '', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : True, 'add_links': True, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
#                       4:{'name':'CO-MSII-fv', "derived_from": "MSII",'class':'CO-MSII', 'method':'MSII_feature_vector', 'stage':4, 'parameters':'', 'add_labels' : True, 'add_links': True, 'variables':{'labelname':'_scar-labels', "graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':'','metadata': []}}}}

# labelfilepath

# %%
#kwargs['scale_method'], kwargs[],kwargs['num_radii'])kwargs[
# 
scale_method = 'scale_continous_volume_dist_rev'
max_radius = 1
num_radii = 13

json_dicts ={3:{1:{'name': 'GMCF', 'stage': 1, 'class': 'GigaMesh', 'method': '', 'variables': {}, 'add_labels' : False, 'add_links' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
                2:{'name': 'MSII_single_feature', 'stage': 2, 'class': 'GigaMesh', 'method': 'MSII_single_feature', 'add_labels' : False, 'parameters':'','add_links' : False, "variables": { 
                    'arguments':  ' '.join([''
                                            # '-1',
                                            #'-2',
                                            # '--no-normals-file'
                                            ]), 'scale_method':scale_method,'max_rad': max_radius,'num_radii':num_radii,'voxels':256},
                'metadata': ['']}}}

# %%
path = "/home/linsel/Documents/PhD/Data/Cologne" 
# folder = 'Cologne_2022_ANNO'
# folder = 'Cologne-test-knapping_202307'

# path = "/home/linsel/Downloads" 
folder = "Cologne_202402"
path = "/home/linsel/Documents/PhD/Data/Cologne/Cologne_202402" 
folder ='Cologne_202402_dat'

for key,json_dict in json_dicts.items():

    run_workflow (path, folder, json_dict)
# Out:
# ['feature', 'GMCF']
# GMCF
# MSII_single_feature
# Begin to process 673_GMCF_r0.31_n0_v256.info.txt
# Begin to process 673_GMCF.ply
# scale_continous_volume_dist_rev 1 13
# -r 1.00
# ~/Documents/GigaMesh/230715_gigamesh/build-GigaMesh-Desktop_Qt_5_15_2_GCC_64bit-Debug/cli/gigamesh-featurevectors  -r 1.00 -n 0 -l 256 "/home/linsel/Documents/PhD/Data/Cologne/Cologne_202402/Cologne_202402_dat/Cologne_202402_dat_01_GMCF//673_GMCF.ply"
# [GigaMesh] ----------------------------------------------------------------------------------
# [GigaMesh] Package version: 230707
# [GigaMesh] ..................................................................................
# [GigaMesh] Built by: linsel@linsel-ThinkPad-P15-Gen-2i
# [GigaMesh] ..... on: 15.Jul.23
# [GigaMesh] .... for: MLU Open Source
# [GigaMesh] Git SHA1: 36720a3c373fdba79ea012178bca8790b8f881e9
# [GigaMesh] ----------------------------------------------------------------------------------
# ...

# %%
from FolderMinions import *

path = "/home/linsel/Documents/PhD/Data/Cologne" 
folder = 'Cologne_2022_ANNO'

ply_information = get_ply_processing_information (path,folder)

ply_information ['893']
# Out:
# {'': {'_895_GMCF_r1.00_n4_v256.volume_distance-vector-nrad16.txt': {'path': '/home/linsel/Documents/PhD/Data/Cologne/Cologne_2022_ANNO/Cologne_2022_ANNO_04_CO-MSII',
#    'step': '04',
#    'preprocessed': '_895_GMCF_r1.00_n4_v256.volume_distance-vector-nrad16'},
#   '_895_GMCF_r1.00_n4_v256.volume_angle-vector-nrad16.txt': {'path': '/home/linsel/Documents/PhD/Data/Cologne/Cologne_2022_ANNO/Cologne_2022_ANNO_04_CO-MSII',
#    'step': '04',
#    'preprocessed': '_895_GMCF_r1.00_n4_v256.volume_angle-vector-nrad16'},
#   '_893_GMCF_r1.00_n4_v256.volume_angle-vector-nrad16.txt': {'path': '/home/linsel/Documents/PhD/Data/Cologne/Cologne_2022_ANNO/Cologne_2022_ANNO_04_CO-MSII',
#    'step': '04',
#    'preprocessed': '_893_GMCF_r1.00_n4_v256.volume_angle-vector-nrad16'},
#   '_893_GMCF_r1.00_n4_v256.volume_max-angle-vector-nrad16.txt': {'path': '/home/linsel/Documents/PhD/Data/Cologne/Cologne_2022_ANNO/Cologne_2022_ANNO_04_CO-MSII',
#    'step': '04',
# ...

# %%
# from WorkFlowAssistant import WorkflowAssistant

# if __name__ == '__main__':

#     WA = WorkflowAssistant()

#     WA.run_GUI()

# %%
{2:{'name': 'ANNO', 'stage': 2, 'class': '', 'method': '', 'parameters': {'preprocessed': '_GMFC'}, 'variables': [''], 'preprocessed': '_GMFC', 'metadata': ['']},
3:{'name':'LABL','stage':3, 'class': 'transform_labelledmesh','method': 'ridge_color_to_scar_labels','parameters':'','variables':{'tresh': 20,'ending': '.ply','preprocessed': ''},'metadata':['_CC-labels','_scar-labels']}}
# Out:
# {2: {'name': 'ANNO',
#   'stage': 2,
#   'class': '',
#   'method': '',
#   'parameters': {'preprocessed': '_GMFC'},
#   'variables': [''],
#   'preprocessed': '_GMFC',
#   'metadata': ['']},
#  3: {'name': 'LABL',
#   'stage': 3,
#   'class': 'transform_labelledmesh',
#   'method': 'ridge_color_to_scar_labels',
#   'parameters': '',
#   'variables': {'tresh': 20, 'ending': '.ply', 'preprocessed': ''},
#   'metadata': ['_CC-labels', '_scar-labels']}}

# %%
from QNodeEditor import Node

class AddNode(Node):
    code = 0  # Unique code for each node type
    
    def create(self):
        self.title = 'Addition'  # Set the node title
        
        self.add_label_output('Output')  # Add output socket
        self.add_value_input('Value 1')  # Add input socket for first value
        self.add_value_input('Value 2')  # Add input socket for second value
        
    def evaluate(self, values: dict):
        result = values['Value 1'] + values['Value 2']  # Add 'Value 1' and 'Value 2'
        self.set_output_value('Output', result)         # Set as value for 'Output'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from QNodeEditor import Node
#       3 class AddNode(Node):
#       4     code = 0  # Unique code for each node type
#
# File ~/anaconda3/envs/PyGUI/lib/python3.12/site-packages/QNodeEditor/__init__.py:3
#       1 """Module containing all elements for a node editor in PyQt5"""
#       2 __version__ = "1.0.5"
# ----> 3 from .scene import NodeScene
#       4 from .node import Node
#       5 from .entry import Entry
#
# File ~/anaconda3/envs/PyGUI/lib/python3.12/site-packages/QNodeEditor/scene.py:12
#       9 from typing import TYPE_CHECKING, Iterable, Type, overload, Optional
#      10 from functools import partial
# ---> 12 from PyQt5.QtWidgets import QWidget
#      13 from PyQt5.QtCore import QObject, QThread, pyqtSignal
#      14 from networkx import DiGraph, find_cycle, NetworkXNoCycle, has_path
#
# ...

# %%
import dearpygui.dearpygui as dpg
dpg.create_context()
# Configure viewport
dpg.create_viewport(title="Tetris Game")
dpg.configure_viewport(0, x_pos=0, y_pos=0, width=1000, height=790)
dpg.set_viewport_max_height(790)
dpg.set_viewport_max_width(1000)
dpg.set_viewport_min_height(790)
dpg.set_viewport_min_width(100)


dpg.create_context()

with dpg.window(label="Tutorial"):
    with dpg.menu_bar():
        with dpg.menu(label="Themes"):
            dpg.add_menu_item(label="Dark")
            dpg.add_menu_item(label="Light")
            dpg.add_menu_item(label="Classic")

dpg.create_viewport(title='Custom Title', width=800, height=600)
dpg.setup_dearpygui()
dpg.show_viewport()
# dpg.start_dearpygui()
# dpg.destroy_context()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
dpg.create_viewport(title='Custom Title', width=800, height=600)
# dpg.setup_dearpygui()
# dpg.show_viewport()
dpg.show_viewport()


# dpg.set_primary_window(window=welcome_screen, value=True)
# dpg.setup_dearpygui()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import dearpygui.dearpygui as dpg

dpg.create_context()
dpg.create_viewport(width=300, height=200)
dpg.setup_dearpygui()

with dpg.window(label="Example Window", tag="Primary"):
    dpg.add_button(label="delete custom_series using parent", callback=lambda: dpg.delete_item("win", children_only=True))
    dpg.add_button(label="delete custom_series using tag", callback=lambda: dpg.delete_item("tricky_custom_series"))
    with dpg.child_window(tag="win"):
        with dpg.plot(width=-1, height=-1):
            dpg.add_plot_axis(dpg.mvXAxis)
            with dpg.plot_axis(dpg.mvYAxis) as yaxis:
                dpg.add_custom_series([], [], 2, tag="tricky_custom_series")
                print(f"Before delete_item(): {dpg.get_item_children(yaxis, 1)}")
                dpg.delete_item("tricky_custom_series")
                print(f"After delete_item(): {dpg.get_item_children(yaxis, 1)}")
                dpg.add_custom_series([], [], 2, tag="tricky_custom_series")
                print(f"After add_custom_series(): {dpg.get_item_children(yaxis, 1)}")
 
dpg.show_viewport()
dpg.set_primary_window("Primary", True)
dpg.start_dearpygui()
dpg.destroy_context()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import dearpygui.dearpygui as dpg

with dpg.window(tag="Primary Window"):
    dpg.add_text("Hello, world")

dpg.create_viewport(title='Custom Title', width=600, height=200)
dpg.setup_dearpygui()
# dpg.show_viewport()
# dpg.set_primary_window("Primary Window", True)
# dpg.start_dearpygui()
# dpg.destroy_context()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
obj = GraphEvaluation ()

# LabelledMesh init
path = kwargs ['path'] 
id = kwargs ['id']
preprocessed = kwargs ['preprocessed']
labelname = kwargs ['labelname']
params = kwargs ['params'] 



# Data import 
# obj.load_labelled_mesh(path,id,preprocessed,labelname)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 obj = GraphEvaluation ()
#       3 # LabelledMesh init
#       4 path = kwargs ['path']
#
# NameError: name 'GraphEvaluation' is not defined

# %% [markdown]
# ## Add more templates
