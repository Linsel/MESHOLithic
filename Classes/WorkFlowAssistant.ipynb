# %%
import os,sys
from functools import reduce

currentdir = os.getcwd()
parentdir = os.path.dirname(currentdir)
gparentdir = os.path.dirname(parentdir)
ggparentdir = os.path.dirname(gparentdir)

sys.path.insert(0, '/'.join([gparentdir,'prototyping'])) 
sys.path.insert(0, '/'.join([parentdir])) 
sys.path.insert(0, '/'.join([gparentdir,'minions'])) 
sys.path.insert(0, '/'.join([gparentdir])) 
sys.path.insert(0, '/'.join([parentdir,'Functions','Procedures'])) 

from GigaMeshMinions import command_line_GigaMesh
from Functions.WorkFlow import run_workflow

import json

# %%
# json_dict = {1:{'name': 'GMAO', 'class': 'GigaMesh', 'stage': 1, 'method': '', 'parameters': '', 'add_labels' : False, 'variables': '', 'processed': '_GMAO', 'metadata': ['']},
# 2:{'name': 'GMCF', 'class': '', 'stage': 2, 'method': '', 'variables': {}, 'parameters': '-m "original, lithic"', 'add_labels' : False, 'processed': '_GMCF', 'metadata': ['mesh_polish']},
# 3:{'name': 'MSII', 'class': '', 'stage': 3, 'method': '', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
# 4:{"name": "CO_concavity", "class": "MSII_CO", "method": "CO_concavity", "stage": 4, "parameters": "", "variables": {"graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16, "preprocessed":"","labelname": "_scar-labels"}, "processed": "", "labelname": "_GMCF_c_scar-labels", "metadata": [""]}}


# json_dicts = {1: {1:{'name': 'GMAO', 'stage': 1, 'class': 'GigaMesh', 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
# 2:{'name': 'GMCF', 'stage': 2, 'class': 'GigaMesh', 'method': 'gigamesh-clean', 'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
# 3:{'name': 'MSII', 'stage': 3, 'class': '', 'method': '', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
# 4:{'name':'MSII_1D','stage':4,'class':'MSII_CO','method':'MSII', 'parameters':'', 'add_labels' : True, 'variables':{'labelname':'_scar-labels', "graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''}}}}

# json_dicts = {0:{1:{'name': 'GMAO', "derived_from": "MEAS", 'class': 'GigaMesh', 'stage': 1, 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
#                  2:{'name': 'ANNO', 'stage': 2, 'class': '', 'method': '', 'parameters': {'preprocessed': '_GMFC'}, 'variables': [''], 'preprocessed': '_GMFC', 'metadata': ['']},
#                  3:{'name':'LABL','stage':3, 'class': 'transform_labelledmesh','method': 'ridge_color_to_scar_labels','parameters':'','variables':{'tresh': 20,'ending': '.ply','preprocessed': ''},'metadata':['_CC-labels','_scar-labels']}}}



# json_dicts.update ({1:{1:{'name': 'GMAO', "derived_from": "MEAS", 'class': 'GigaMesh', 'stage': 1, 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
#                        2:{'name': 'GMCF', 'stage': 2, 'class': 'GigaMesh', 'method': 'gigamesh-clean', 'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
#                        3:{'name': 'MSII', 'stage': 3, 'class': 'GigaMesh', 'method': 'gigamesh-featurevectors', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']}}})

json_dicts = {1: {1:{'name': 'GMAO', 'stage': 1, 'class': 'GigaMesh', 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
                  2:{'name': 'GMCF', 'stage': 2, 'class': 'GigaMesh', 'method': 'gigamesh-clean', 'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
                  3:{'name': 'MSII', 'stage': 3, 'class': '', 'method': '', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
                  4:{'name':'MSII-1D','stage':4,'class':'CO-MSII','method':'MSII', 'parameters':'', 'add_labels' : True, 'add_links': True, 'variables':{'labelname':'_scar-labels', "graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''},"metadata": [""]}}}


json_dicts = {3:{1:{'name': 'GMAO', "derived_from": "MEAS", 'class': 'GigaMesh', 'stage': 1, 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
                      2:{'name': 'GMCF', "derived_from": "GMAO", 'class': 'GigaMesh', 'stage': 2, 'method': 'gigamesh-clean', 'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
                      3:{'name': 'MSII', "derived_from": "MSII", 'class': '', 'stage': 3, 'method': '', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
                      4:{"name": "CO-Concavity", "derived_from": "CO_concavity", "class": "CO-MSII", "method": "CO_concavity", "stage": 4, "parameters": "", 'add_labels' : True, 'add_links': True, "variables": {"labelname": "_scar-labels","graphname": "max", "diameter": 1, "parameters": ["quality"], "n_rad": 4, "preprocessed":""}, "processed": "", "labelname": "_scar-labels"},"metadata": []}}


# json_dicts = {1: {1:{'name': 'GMAO', 'stage': 1, 'class': 'GigaMesh', 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']}}}


json_dicts = {4:{1:{'name': 'GMAO', "derived_from": "MEAS", 'class': 'GigaMesh', 'stage': 1, 'method': '', 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
                      2:{'name': 'GMCF', "derived_from": "GMAO", 'class': 'GigaMesh', 'stage': 2, 'method': 'gigamesh-clean', 'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
                      3:{'name': 'MSII', "derived_from": "MSII", 'class': '', 'stage': 3, 'method': '', 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
                      4:{'stage':4,'class':'CO-MSII','name':'CO-MSII','method':'MSII_feature_vector', 'parameters':'', 'add_labels' : True, 'add_links': True, 'variables':{'labelname':'_scar-labels', "graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''},'metadata': []}}}

# %%
path = "/home/linsel/Documents/PhD/Data/Cologne" 
folder = 'Cologne_2022_ANNO'
folder = 'Cologne_test_knapping_202307'

for key,json_dict in json_dicts.items():
    print(key)
    run_workflow (path, folder, json_dict)
# Out:
# 4
# Begin to process TK-002_GMOCF_r1.00_n4_v256.volume_scar-labels.txt
# Begin to process TK-004_GMOCF_r1.00_n4_v256.volume_scar-labels.txt
# Begin to process TK-007_GMOCF_r1.00_n4_v256.volume_scar-labels.txt
# Begin to process too
# Begin to process too_big
# Begin to process TK-002_GMOCF_r1.00_n4_v256.volume.ply
# done (1/7)
# CO_prepare_procedure done (2/7)
# done (3/7)
# done (4/7)
# done (5/7)
# done (6/7)
# Has no edge file
# ...

# %%
from FolderMinions import *



path = "/home/linsel/Documents/PhD/Data/Cologne" 
folder = 'Cologne_2022_ANNO'

ply_information = get_ply_processing_information (path,folder)

ply_information #['893']
# for 

# 'r16-angle-vector', 'r16-distance-vector', 'v256.volume', 

# inside-mean-curv-r9
# Out:
# {'893': {'893_GMCF_r1.00_n4_v256.volume_r16-max-angle-vector.txt': {'ID': '893',
#    'path': '/home/linsel/Documents/PhD/Data/Cologne/Cologne_2022_ANNO/Cologne_2022_ANNO_04_MSII-1D',
#    'step': '04',
#    'preprocessed': '_GMCF_r1.00_n4_v256.volume_r16-max-angle-vector'},
#   '893_GMCF_r1.00_n4_v256.volume_r16-angle-vector.txt': {'path': '/home/linsel/Documents/PhD/Data/Cologne/Cologne_2022_ANNO/Cologne_2022_ANNO_04_MSII-1D',
#    'step': '04',
#    'preprocessed': '_GMCF_r1.00_n4_v256.volume_r16-angle-vector'},
#   '893_GMCF_r1.00_n4_v256.volume_r16-distance-vector.txt': {'path': '/home/linsel/Documents/PhD/Data/Cologne/Cologne_2022_ANNO/Cologne_2022_ANNO_04_MSII-1D',
#    'step': '04',
#    'preprocessed': '_GMCF_r1.00_n4_v256.volume_r16-distance-vector'},
#   '893_GMCF.ply': {'path': '/home/linsel/Documents/PhD/Data/Cologne/Cologne_2022_ANNO/Cologne_2022_ANNO_01_GMCF',
#    'step': '01',
#    'preprocessed': '_GMCF'},
# ...

# %%
from WorkFlowAssistant import WorkflowAssistant

if __name__ == '__main__':

    WA = WorkflowAssistant()

    WA.run_GUI()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/linsel/anaconda3/envs/PhD/lib/python3.9/tkinter/__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "/home/linsel/Documents/PhD/segmentation/prototyping/Classes/WorkFlowAssistant.py", line 262, in update_dict_from_import_text
#     updated_dict = ast.literal_eval(self.import_text.get(1.0, tk.END))
#   File "/home/linsel/anaconda3/envs/PhD/lib/python3.9/ast.py", line 62, in literal_eval
#     node_or_string = parse(node_or_string, mode='eval')
#   File "/home/linsel/anaconda3/envs/PhD/lib/python3.9/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#   File "<unknown>", line 1
#
#     ^
# SyntaxError: unexpected EOF while parsing
# 1
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/linsel/Documents/PhD/segmentation/minions/FolderMinions.py", line 82, in get_last_step
#     return last_step
# ...

# %%
{2:{'name': 'ANNO', 'stage': 2, 'class': '', 'method': '', 'parameters': {'preprocessed': '_GMFC'}, 'variables': [''], 'preprocessed': '_GMFC', 'metadata': ['']},
3:{'name':'LABL','stage':3, 'class': 'transform_labelledmesh','method': 'ridge_color_to_scar_labels','parameters':'','variables':{'tresh': 20,'ending': '.ply','preprocessed': ''},'metadata':['_CC-labels','_scar-labels']}}
# Out:
#   Input In [5]
#     1:{'name': 'ANNO', 'stage': 1, 'class': '', 'method': '', 'parameters': '', 'variables': [''], 'preprocessed': '_GMFC', 'metadata': ['']}
#     ^
# SyntaxError: invalid syntax

# %%
{2:{'name': 'ANNO', 'stage': 2, 'class': '', 'method': '', 'parameters': {'preprocessed': '_GMFC'}, 'variables': [''], 'preprocessed': '_GMFC', 'metadata': ['']},
3:{'name':'LABL','stage':3, 'class': 'transform_labelledmesh','method': 'ridge_color_to_scar_labels','parameters':'','variables':{'tresh': 20,'ending': '.ply','preprocessed': ''},'metadata':['_CC-labels','_scar-labels']}}

# %%
{'name':'LABL',
 'stage':3, 
 'class': 'transform_labelledmesh',
 'method': 'ridge_color_to_scar_labels',
 'parameters':'',
 'variables':{'tresh': 20,'ending': '.ply'},
 'processed': '_GMCF_c',
 'metadata':['_CC-labels','_scar-labels']}

# %% [markdown]
# ## Add more templates

# %%
templates = {
'GMAO':{  
	'name':'GMAO',
	'procedure': 'GigaMesh', 
	'stage':'',
	'method':'',
	'parameters':'',
	'variables': '',                         
	'processed':'_GMAO',
	'metadata':['']},
'GMCF':{ 'name':'GMCF',
	'procedure': 'GigaMesh', 
	'stage':'',
	'method':'gigamesh-clean', 
	'variables': {},             
	'parameters':'-m "original, lithic"',
	'processed':'_GMCF',
	'metadata':['mesh_polish']},    
'MSII':{'name':'MSII',
	'procedure': 'GigaMesh', 
	'stage':'',
	'method':'gigamesh-featurevectors',
	'variables': {	'r':1.00,
			'n':4,
			'v':256},                 
	'parameters':'-r 1.00 -n 4 -l 256',
	'processed':'_r1.00_n4_v256',
	'metadata':['info','normal','surface','volume']},
'CO_concavity':{'name':'CO_concavity',
	'procedure': 'MSII',
    'method': 'CO_concavity',
	'stage':'',
	'method':'',
	'parameters':'',
	 'variables':{	  'graphname':'max',
			  'diameter': 1.00,
			  'parameter':'quality',
			  'n_rad': 16},                        
	'processed':'',
	'labelname':'_scar-labels',
	'metadata':['']

}} 

workflow_template_file = ''.join(['workflow_templates.json'])

with open(workflow_template_file,"w") as f:
	json.dump(templates,f)

with open(workflow_template_file,"w") as f:
	json.dump(templates,f)

# %%
workflow = {   1:{  'name':'GMAO',
                    'procedure': 'GigaMesh', 
                    'stage':1,
                    'method':'',
                    'parameters':'',
                    'variables': {},                         
                    'processed':'_GMAO',
                    'metadata':['']}}


workflow.update({2:{ 'name':'GMCF',
                    'procedure': 'GigaMesh', 
                    'stage':2,
                    'method':'gigamesh-clean', 
                    'variables': {},             
                    'parameters':'',
                    'processed':'_GMCF',
                    'metadata':['mesh_polish']}})
                
r,n,v = 1.00,4,256

workflow.update({3:{ 'name':'MSII',
                    'procedure': 'GigaMesh', 
                    'stage':3,
                    'method':'gigamesh-featurevectors',
                    'variables': {'r':'r','n':'n','v':'v'},                 
                    'parameters':'-r {} -n {} -l {}'.format(r,n,v),
                    'processed':'_r{}_n{}_v{}'.format(r,n,v),
                    'metadata':['info','normal','surface','volume']}})

# %%
# import tkinter as tk
# from tkinter import ttk, simpledialog

# def update_display_from_template():
#     selected_template_name = template_combobox.get()
#     selected_template = dictionary_templates.get(selected_template_name, {})
#     display_text.delete(1.0, tk.END)
#     display_text.insert(tk.END, str(selected_template))

# def open_edit_popup():
#     def save_values():
#         # for key, entry in entries.items():
#         #     value = entry.get()
#         #     if value:  # Only update if a value was entered
#         #         selected_template[key] = value

#         # Special handling for nested 'variables' dictionary
#         for var_key in selected_template['variables'].keys():
#             selected_template['variables'][var_key] = variable_entries[var_key].get()
#         popup.destroy()
#         # Close popup after saving
#         popup.destroy()
#         update_display_from_template()

#     selected_template_name = template_combobox.get()
#     global selected_template  # To modify the template directly
#     selected_template = dictionary_templates.get(selected_template_name, {})

#     popup = tk.Toplevel(root)
#     popup.title("Edit Values")
#     variable_entries = {}

#     # Dynamically create a label and entry for each key in the template
#     # for i, key in enumerate(selected_template.keys()):
#     #     tk.Label(popup, text=key).grid(row=i, column=0)
#     #     entry = tk.Entry(popup)
#     #     entry.grid(row=i, column=1)
#     #     entries[key] = entry

#     # Special handling for 'variables' nested dictionary
#     tk.Label(popup, text="variables").grid(row=row, column=0)
#     self.row= 0
#     for key in selected_template['variables'].keys():
#         tk.Label(popup, text=key).grid(row=row, column=0)
#         entry = tk.Entry(popup)
#         entry.insert(0, selected_template['variables'][key])  # Pre-fill current value
#         entry.grid(row=row, column=1)
#         variable_entries[key] = entry
#         self.row+= 1    

#     # Save button
#     save_button = tk.Button(popup, text="Save", command=save_values)
#     save_button.grid(row=len(selected_template)+1, column=0, columnspan=2)

# # Initialize the main Tkinter window
# root = tk.Tk()
# root.title("Nested Dictionary GUI")

# # Dictionary templates
# dictionary_templates = {
#     'Template 1': {'key1': '', 'key2': ''},
#     'Template 2': {'first': '', 'second': ''},
#     'Template 3': {
#         'name': '',
#         'procedure': '',
#         'stage': 3,
#         'method': '',
#         'variables': {'c': '', 'f': '', 'g': ''}
#     }
# }

# # Dropdown menu for selecting a dictionary template
# template_combobox = ttk.Combobox(root, values=list(dictionary_templates.keys()))
# template_combobox.grid(row=0, column=0, sticky="ew", padx=10, pady=5)
# template_combobox.bind('<<ComboboxSelected>>', lambda event: update_display_from_template())

# # Button to open the popup for editing values
# edit_button = tk.Button(root, text="Edit Template Values", command=open_edit_popup)
# edit_button.grid(row=2, column=0, sticky="ew", padx=10, pady=5)

# # Text widget to display the selected dictionary template
# display_text = tk.Text(root, height=15, width=50)
# display_text.grid(row=3, column=0, columnspan=2, sticky="ew", padx=10, pady=5)

# root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/linsel/anaconda3/envs/PhD/lib/python3.9/tkinter/__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "/tmp/ipykernel_137916/2544512847.py", line 41, in open_edit_popup
#     tk.Label(popup, text="variables").grid(row=row, column=0)
# UnboundLocalError: local variable 'row' referenced before assignment

# %%
# class PopupWindow:
#     def __init__(self, parent):
#         top = self.top = tk.Toplevel(parent)
#         top.title("Add Values")
#         self.myLabel = tk.Label(top, text="Enter the radius (float), the number of spheres (2^n) and the  your values separated by commas")
#         self.myLabel.pack()
#         self.myEntryBox = tk.Entry(top, width=50)
#         self.myEntryBox.pack()
#         self.mySubmitButton = tk.Button(top, text='Submit', command=self.send)
#         self.mySubmitButton.pack()
#         self.values = []

#     def send(self):
#         input_values = self.myEntryBox.get()
#         self.values = [value.strip() for value in input_values.split(',')]
#         self.top.destroy()

# class WorkflowAssistant:

#     def __init__(self) -> None:
#         # Initialize your nested dictionary       
#         self.workflow = {} 
#         # Initialize settings dictionary
#         self.settings = {'Path': '', 'Folder': ''}  

#         # Initialize templates dictionary
#         # self.dictionary_templates = {
#         #     'GMAO':{  'name':'GMAO',
#         #             'procedure': 'GigaMesh', 
#         #             'stage':1,
#         #             'method':'',
#         #             'parameters':'',
#         #             'variables': {},                         
#         #             'processed':'_GMAO',
#         #             'metadata':['']},
#         #     'GMCF':{ 'name':'GMCF',
#         #             'procedure': 'GigaMesh', 
#         #             'stage':2,
#         #             'method':'gigamesh-clean', 
#         #             'variables': {},             
#         #             'parameters':'',
#         #             'processed':'_GMCF',
#         #             'metadata':['mesh_polish']},    
#         #     'MSII':{'name':'MSII',
#         #             'procedure': 'GigaMesh', 
#         #             'stage':3,
#         #             'method':'gigamesh-featurevectors',
#         #             'variables': {'r':r,'n':n,'v':v},                 
#         #             'parameters':'-r {} -n {} -l {}'.format(r,n,v),
#         #             'processed':'_r{}_n{}_v{}'.format(r,n,v),
#         #             'metadata':['info','normal','surface','volume']}}  
        
#         self.dictionary_templates = {
#             'GMAO':{  'name':'GMAO',
#                     'procedure': 'GigaMesh', 
#                     'stage':"{}",
#                     'method':'',
#                     'parameters':'',
#                     'variables': {},                         
#                     'processed':'_GMAO',
#                     'metadata':['']},
#             'GMCF':{ 'name':'GMCF',
#                     'procedure': 'GigaMesh', 
#                     'stage':{},
#                     'method':'gigamesh-clean', 
#                     'variables': {},             
#                     'parameters':'',
#                     'processed':'_GMCF',
#                     'metadata':['mesh_polish']},    
#             'MSII':{'name':'MSII',
#                 'procedure': 'GigaMesh', 
#                 'stage':{},
#                 'method':'gigamesh-featurevectors',
#                 'variables': {'r':"{}",'n':"{}",'v':"{}"},                 
#                 'parameters':'-r "{}" -n "{}" -l "{}"',
#                 'processed':'_r"{}"_n"{}"_v"{}"',
#                 'metadata':['info','normal','surface','volume']}} 

#         # Initialize the main Tkinter window
#         self.root = tk.Tk()
#         self.root.title("Workflow Assistant for Processing Artifacts")

#         # Configure the grid layout manager
#         # Configures 2 columns to have equal weight
#         self.root.grid_columnconfigure(0, weight=1)
#         self.root.grid_columnconfigure(1, weight=1)  
#         # Configures a 3. column to have doublr the weight
#         self.root.grid_columnconfigure(2, weight=2)

#         self.create_widgets()

#         self.place_widgets_in_grid()

#         # Initial display update
#         self.update_display()


#     # Start the Tkinter event loop
#     def run_GUI(self):
        
#         self.root.mainloop()

#     def create_widgets (self):

#         # Path entry and browse button
#         self.path_label = tk.Label(self.root, text="Path:")
#         self.path_entry = tk.Entry(self.root, width=50)
#         self.browse_button = tk.Button(self.root, text="Browse...", command=self.browse_path)

#         # Combobox for selecting a subfolder
#         self.subfolder_label = tk.Label(self.root, text="Select Subfolder:")
#         self.subfolder_combobox = ttk.Combobox(self.root, width=47)
#         self.subfolder_combobox.bind('<<ComboboxSelected>>', self.on_subfolder_selection)

#         # Combobox for selecting the main key
#         key_options = [1, 2, 3]  
#         self.key_combobox = ttk.Combobox(self.root, values=key_options)

#         # Combobox for selecting the subkey
#         subkey_options = ['subkey1', 'subkey2', 'subkey3']  # Example subkeys
#         self.subkey_combobox = ttk.Combobox(self.root, values=subkey_options)

#         # Text widget to display the dictionary
#         self.import_text = tk.Text(self.root, height=15, width=50)

#         # Text widget to display the dictionary
#         self.display_text = tk.Text(self.root, height=15, width=50)

#         # Button to add a new key-value pair
#         self.add_single_entry_button = tk.Button(self.root, text="Add Single Entry", command=self.add_entry)

#         # Button to print dictionary
#         # self.print_dictionary_button = tk.Button(self.root, text="Print Dictionary", command=self.print_dictionary)

#         # Button to update workflow from display_text content
#         self.update_button = tk.Button(self.root, text="Update Dictionary from Display", command=self.update_dict_from_display)

#         # Dropdown menu for selecting a dictionary template
#         self.template_combobox = ttk.Combobox(self.root, values=list(self.dictionary_templates.keys()))
#         self.template_combobox.bind('<<ComboboxSelected>>', lambda event: self.update_import_from_template())


#     def place_widgets_in_grid(self):

#         # Place widgets using grid layout
#         self.path_label.grid(row=0, column=0, sticky="ew")
#         self.path_entry.grid(row=0, column=1, sticky="ew")
#         self.browse_button.grid(row=1, column=1, sticky="ew")
#         self.subfolder_label.grid(row=2, column=0, sticky="ew")
#         self.subfolder_combobox.grid(row=2, column=1, sticky="ew")
#         self.add_single_entry_button.grid(row=3, column=0, sticky="ew")
#         # self.print_dictionary_button.grid(row=3, column=1, sticky="ew")
#         self.template_combobox.grid(row=3, column=1, sticky="ew")

#         self.import_text.grid(row=4, column=0, columnspan=2, sticky="ew")
#         self.update_button.grid(row=5, column=1, sticky="ew")
#         self.display_text.grid(row=0, column=2, rowspan=6, sticky="ew")


#     def add_entry(self):
#         key = self.key_combobox.get()
#         if not key:
#             # No key selected, do nothing
#             return  

#         if key not in self.workflow:
#             self.workflow[key] = {}

#         subkey = self.subkey_combobox.get()
#         if not subkey:
#             # No subkey selected, do nothing
#             return  

#         value = simpledialog.askstring("Input", "Enter value for '{} > {}':".format(key, subkey), parent=self.root)
#         # Only add if value is not empty
#         if value:  
#             self.workflow[key][subkey] = value
#             self.update_display()

#     # Function to display the current state of the dictionary
#     def update_display(self):
#         self.display_text.delete(1.0, tk.END)  # Clear current text
#         self.display_text.insert(tk.END, str(self.workflow))  # Display updated dictionary

#     def retrieve_input(self):
#         return self.root.myText_Box.get("1.0",'end-1c')

#     # def print_dictionary(self):
#     #     print(self.workflow)

#     def update_import_from_template(self):
#         # Get the name of the selected template
#         self.selected_template_name = self.template_combobox.get()
#         # Find the corresponding dictionary template
#         self.selected_template = self.dictionary_templates.get(self.selected_template_name, {})
#         # Update the display_text widget
#         self.import_text.delete(1.0, tk.END)  # Clear current content
#         self.import_text.insert(tk.END, str(self.selected_template))  # Insert the selected template

#     def update_display_from_template_with_values(self):
#         selected_template_name = self.template_combobox.get()
#         selected_template = self.dictionary_templates.get(selected_template_name, {})
        
#         # Launch the popup window for input
#         popup = PopupWindow(self.root)
#         self.root.wait_window(popup.top)
        
#         # Here, adjust the code below to fit where you want to insert the values in your template
#         # Example: Inserting values directly if the template is a list
#         if isinstance(selected_template, list):
#             selected_template.extend(popup.values)
#         elif isinstance(selected_template, dict):
#             # Example: Adding values to a specific key in the dictionary
#             key_to_update = 'your_specific_key'
#             selected_template[key_to_update] = popup.values
        
#         self.import_text.delete(1.0, tk.END)
#         self.import_text.insert(tk.END, str(selected_template))


#     def update_dict_from_display(self):
#         try:
#             # Attempt to safely evaluate the text content as a Python literal
#             updated_dict = ast.literal_eval(self.import_text.get(1.0, tk.END))
#             if isinstance(updated_dict, dict):
#                 self.workflow.update(updated_dict) 
#                 messagebox.showinfo("Success", "Dictionary updated successfully.")
#                 self.update_display()
#             else:
#                 messagebox.showerror("Error", "The content is not a valid dictionary.")
#         except ValueError as e:
#             messagebox.showerror("Error", "Invalid content. Please ensure it's a valid dictionary format.")     

#     ################################################
#     # select path and subfolder

#     # Function to browse for a directory path
#     def browse_path(self):
#         directory = filedialog.askdirectory()
#         if directory:  # Ensure a directory was selected
#             self.path_entry.delete(0, tk.END)
#             self.path_entry.insert(0, directory)
#             self.settings['Path'] = directory 
#             self.update_subfolders(directory)

#     # Function to update the subfolder dropdown based on the selected path
#     def update_subfolders(self,directory):
#         subfolders = [f.name for f in os.scandir(directory) if f.is_dir()]
#         self.subfolder_combobox['values'] = subfolders
#         if subfolders:
#             self.subfolder_combobox.current(0)  # Automatically select the first subfolder

#     ################################################
#     # Event update subfolder
#     def on_subfolder_selection(self,event):
#         self.settings['Folder'] = self.subfolder_combobox.get()

# if __name__ == '__main__':

#     WA = WorkflowAssistant()

#     WA.run_GUI()
