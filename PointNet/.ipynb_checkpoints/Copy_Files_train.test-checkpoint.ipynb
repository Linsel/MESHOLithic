# %%
import os 
import shutil
import random
import glob
import pandas as pd

path = '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/'

target_name = 'ID'

target = 'scars/'

len_data = int(len([ item for item in os.listdir()]))

scarlist = os.listdir(path)

print('{}{}'.format(path,target))

if os.path.isdir('{}{}'.format(path,target)) is False:
    os.makedirs('{}{}'.format(path,target))
    os.makedirs('{}{}{}'.format(path,target,'test/'))
    os.makedirs('{}{}{}'.format(path,target,'train/'))
    os.makedirs('{}{}{}'.format(path,target,'valid/'))

for scar in scarlist:
    print(random.sample(glob.glob('{}*'.format(path)),2))
    for c in random.sample(glob.glob('{}*'.format(path)),int(len_data * 75 / 100)):        
        if c.endswith('.ply') and c.split('/')[len(c.split('/'))-1].split('.')[1] == 'comp':

            shutil.move('{}'.format(c),'{}{}train/{}'.format(path,target,c.split('/')[len(c.split('/'))-1]))
            
                        
    for c in random.sample(glob.glob('{}*'.format(path)),int(len_data * 15 / 100)):        
        if c.endswith('.ply') and c.split('/')[len(c.split('/'))-1].split('.')[1] == 'comp':

            shutil.move('{}'.format(c),'{}{}test/{}'.format(path,target,c.split('/')[len(c.split('/'))-1]))

    for c in random.sample(glob.glob('{}*'.format(path)),int(len_data * 10 / 100)):        
        if c.endswith('.ply') and c.split('/')[len(c.split('/'))-1].split('.')[1] == 'comp':
#             print(c)
            shutil.move('{}'.format(c),'{}{}valid/{}'.format(path,target,c.split('/')[len(c.split('/'))-1]))
#     for c in random.sample(glob.glob('{}*'.format(bf_target)),int(len_data * 15 / 100)):
#         shutil.copy(c,'test/{}'.format(bf_target))
#     for c in random.sample(glob.glob('{}*'.format(bf_target)),int(len_data * 10 / 100)):
#         shutil.copy(c,'valid/{}'.format(bf_target))
# Out:
# /media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/scars/
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5244.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/764.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10356.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/737.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2281.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/scars']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5219.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2427.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/749.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1464.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2280.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/842.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10454.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/75.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/749.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/842.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/104.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1424.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2296.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4124.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1649.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/713.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2296.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1549.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/728.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4124.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1552.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/737.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/104.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/691.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1645.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/800.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2296.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10454.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/728.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1549.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/729.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/700.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/752.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/798.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10360.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9433.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1549.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2280.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/6626.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/773.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/713.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9433.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2280.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10360.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2281.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/842.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/710.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1549.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/713.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/749.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/691.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/720.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2280.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/709.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10356.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/207.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2296.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10350.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1552.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/757.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10360.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/800.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10350.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/842.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/749.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5244.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/691.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9433.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9337.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2296.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1467.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5244.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/695.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4124.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5244.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/710.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/207.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4126.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2281.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/31.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1549.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1649.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4636.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5194.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/752.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/689.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4124.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/207.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/757.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/202.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1464.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1649.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/737.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10350.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5244.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/720.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/700.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/695.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/757.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1464.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2281.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10350.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/773.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/31.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/773.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/729.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/6684.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/742.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5244.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/728.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9337.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/700.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10361.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/710.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/31.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/207.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/31.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5194.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5244.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/metadata.json']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/801.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/742.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/713.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2296.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/6853.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/752.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/752.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5169.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/729.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/728.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/842.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/757.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/6626.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/709.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4501.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10358.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/700.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/773.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1464.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9337.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1464.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/31.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10356.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/757.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/728.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2280.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1645.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5219.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/31.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1464.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/710.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10354.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10358.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4636.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/720.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10454.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/104.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/689.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1549.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1597.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/31.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2427.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/742.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/31.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/773.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9337.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/695.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/737.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10360.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/metadata.json']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/scars', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4636.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1522.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/728.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/6684.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/737.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/104.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/75.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9433.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2490.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1464.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1464.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/6626.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1522.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1552.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/75.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/6684.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5194.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10350.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/713.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5219.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/742.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/695.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1549.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2296.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5194.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1645.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/722.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10350.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/metadata.json']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1522.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4501.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/6853.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4124.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9337.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/689.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1467.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1597.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/749.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1597.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/757.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2280.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1549.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/6626.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4126.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5244.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/689.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/728.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10358.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2296.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4124.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9433.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1522.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/75.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/691.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/31.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/10360.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1597.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/2427.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/764.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/5219.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/207.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1549.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/752.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/709.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/757.txt']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1597.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1649.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/737.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/202.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/4501.txt', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/9433.ply']
# ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/1645.ply', '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/773.ply']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys
from sklearn.decomposition import PCA    

paths = ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_Base/']
import numpy as np
from MorseTheory import pointclouds

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from os import listdir
from os.path import isfile, join

from EvaluateSegmentation.read_ply import read_ply

lists = pd.DataFrame(columns=['filename', 'name', 'key', 'data_mean', 'data_min', 'lower_quantile','data_median','upper_quantile','data_max','data_std','data_var']) 
lists_2 = pd.DataFrame(columns=['filename', 'name', 'key', 'data_mean', 'data_min', 'lower_quantile','data_median','upper_quantile','data_max','data_std','data_var']) 
combined = pd.DataFrame(columns=['filename','type', 'data'])
scardict = {}

for num,path in enumerate(paths):

    files = os.listdir(path)
    failed_sum = 0
    failed_list = []

    for gt_filename in files:
        gt_name = gt_filename.split('.')
        if (gt_name[0] == 'scars'):
            continue
#         try:
        #print(gt_name)    
        if  gt_filename.endswith('.ply'): #gt_name[1] != 'comp' and
            target = gt_name[0] + '/'
            print (path+target)
            if os.path.isdir('{}{}'.format(path,'PartAnnotation/')) is False:          
                os.makedirs('{}{}'.format(path,'PartAnnotation/'))




            df = pd.read_csv(path + gt_name[0] + '.txt',sep=' ', header = None, skiprows = 10,encoding='Latin-1')
            onehotencode =  pd.get_dummies(df[1], columns=np.unique(df[1]))
            
            Poclar = pointclouds.point_cloud_arr()

            filename,quality_index = path + gt_filename,3

            Poclar.load_ply(filename, quality_index)
            Poclar.create_point_cloud()
            
            
            for label in np.unique(df[1]):
             
                output = pd.concat([df[0],onehotencode[label]],axis=1)
    
                output = output.sort_values(by=[0]) 
                if os.path.isdir('{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/')) is False:          
                    os.makedirs('{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points/'))
                    os.makedirs('{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points_label/'))
                    os.makedirs('{}{}{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points_label/',label,'/'))
                    
                '{}{}{}{}{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points_label/',label,'/',gt_filename[:-4],'.seg')   
                output[label].to_csv('{}{}{}{}{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points_label/',label,'/',gt_filename[:-4],'.seg'),header=False, index=False)    
                
                if os.path.isdir('{}{}{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points/',gt_filename[:-4],'.pts')) is False:


                    pd.DataFrame(Poclar.point_cloud[:,:3],columns=['x','y','z']).to_csv('{}{}{}{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points/',gt_filename[:-4],'.pts'), sep=' ', header=False, index=False)

                    pd.concat([df[0],onehotencode[label]],axis=1)
                                    
#                 if gt_filename [:-4] + '_stats.csv' in files:
#                     read_list = pd.read_csv(path + gt_filename [:-4] + '_stats.csv')
#                     lists = pd.concat([lists,read_list])
#                     print (gt_filename)
#                     continue

#                 else:
#                     Poclar = pointclouds.point_cloud_arr()

#                     filename,quality_index = path + gt_filename,3
#                     print(filename)

#                     Poclar.load_ply(filename, quality_index)
#                     Poclar.create_point_cloud()



#         #                 #print(Poclar.df_list)
#         #                 #print(Poclar.df_data)

#                     lists = pd.concat([lists,Poclar.stats])
#                     #combined = pd.concat([combined,Poclar.df_data])
#                     print(1)
#         except:
#             print(2)

#             failed_list.append(gt_filename)

#             failed_sum += 1
# Out:
# /media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_Base/10454/
# Time read data file: 6.395505278007477
# Time read and prepare data: 26.042859462002525
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [71], in <cell line: 11>()
#      53 '{}{}{}{}{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points_label/',label,'/',gt_filename[:-4],'.seg')
#      54 output[label].to_csv('{}{}{}{}{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points_label/',label,'/',gt_filename[:-4],'.seg'),header=False, index=False)
# ---> 56 if os.path.isdir('{}{}{}{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points/',gt_filename[:-4],'.pts')) is False:
#      59     pd.DataFrame(Poclar.point_cloud[:,:3],columns=['x','y','z']).to_csv('{}{}{}{}{}{}'.format(path,'PartAnnotation/','GrottaDiFumane/points/',gt_filename[:-4],'.pts'), sep=' ', header=False, index=False)
#      61     pd.concat([df[0],onehotencode[label]],axis=1)
#
# IndexError: Replacement index 5 out of range for positional args tuple
