# %%
import os
import glob
import trimesh
import numpy as np
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers
import matplotlib.pyplot as plt

tf.random.set_seed(1234)

# %%
# DATA_DIR = tf.keras.utils.get_file(
#     "modelnet.zip",
#     "http://3dvision.princeton.edu/projects/2014/3DShapeNets/ModelNet10.zip",
#     extract=True,
# )

# print(os.path.dirname(DATA_DIR))
DATA_DIR = '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/' #os.path.join(os.path.dirname(DATA_DIR), "ModelNet10")

# %%
DATA_DIR
# Out:
# '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/'

# %%
mesh = trimesh.load(os.path.join(DATA_DIR, "chair/train/chair_0001.off"))
mesh.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 mesh = trimesh.load(os.path.join(DATA_DIR, "chair/train/chair_0001.off"))
#       2 mesh.show()
#
# File ~/anaconda3/envs/PhD/lib/python3.9/site-packages/trimesh/exchange/load.py:111, in load(file_obj, file_type, resolver, force, **kwargs)
#     103     return file_obj
#     105 # parse the file arguments into clean loadable form
#     106 (file_obj,  # file- like object
#     107  file_type,  # str, what kind of file
#     108  metadata,  # dict, any metadata from file name
#     109  opened,    # bool, did we open the file ourselves
#     110  resolver   # object to load referenced resources
# --> 111  ) = parse_file_args(file_obj=file_obj,
#     112                      file_type=file_type,
#     113                      resolver=resolver)
#     115 try:
#     116     if isinstance(file_obj, dict):
#     117         # if we've been passed a dict treat it as kwargs
#
# File ~/anaconda3/envs/PhD/lib/python3.9/site-packages/trimesh/exchange/load.py:623, in parse_file_args(file_obj, file_type, resolver, **kwargs)
#     620             raise ValueError(
#     621                 'use load_remote to load URL: {}'.format(file_obj))
#     622         elif file_type is None:
# --> 623             raise ValueError('string is not a file: {}'.format(file_obj))
#     625 if file_type is None:
#     626     file_type = file_obj.__class__.__name__
#
# ValueError: string is not a file: /media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/PointNet_base/chair/train/chair_0001.off

# %%
points = mesh.sample(2048)

fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection="3d")
ax.scatter(points[:, 0], points[:, 1], points[:, 2])
ax.set_axis_off()
plt.show()

# %%
def parse_dataset(num_points=2048):

    train_points = []
    train_labels = []
    test_points = []
    test_labels = []
    class_map = {}
    folders = glob.glob(os.path.join(DATA_DIR, "[!README]*"))

    for i, folder in enumerate(folders):
        print("processing class: {}".format(os.path.basename(folder)))
        # store folder name with ID so we can retrieve later
        class_map[i] = folder.split("/")[-1]
        # gather all files
        train_files = glob.glob(os.path.join(folder, "train/*"))
        test_files = glob.glob(os.path.join(folder, "test/*"))

        for f in train_files:
            train_points.append(trimesh.load(f).sample(num_points))
            train_labels.append(i)

        for f in test_files:
            test_points.append(trimesh.load(f).sample(num_points))
            test_labels.append(i)

    return (
        np.array(train_points),
        np.array(test_points),
        np.array(train_labels),
        np.array(test_labels),
        class_map,
    )

# %%
NUM_POINTS = 2048
NUM_CLASSES = 1
BATCH_SIZE = 32

train_points, test_points, train_labels, test_labels, CLASS_MAP = parse_dataset(
    NUM_POINTS
)
# Out:
# processing class: 31.comp.1_stats.csv
# processing class: 31.comp.2_stats.csv
# processing class: 31.comp.3_stats.csv
# processing class: 31.comp.4_stats.csv
# processing class: 31.comp.5_stats.csv
# processing class: 31.comp.6_stats.csv
# processing class: 31.comp.7_stats.csv
# processing class: 31.comp.8_stats.csv
# processing class: 31.comp.9_stats.csv
# processing class: 31.comp.10_stats.csv
# processing class: 31.comp.11_stats.csv
# processing class: 31.comp.12_stats.csv
# processing class: 31.comp.13_stats.csv
# processing class: 31.ply
# processing class: 31.txt
# processing class: 75.comp.1_stats.csv
# processing class: 75.comp.2_stats.csv
# processing class: 75.comp.3_stats.csv
# processing class: 75.comp.4_stats.csv
# processing class: 75.comp.5_stats.csv
# processing class: 75.comp.6_stats.csv
# processing class: 75.ply
# processing class: 75.txt
# processing class: 104.comp.1_stats.csv
# processing class: 104.comp.2_stats.csv
# processing class: 104.comp.3_stats.csv
# processing class: 104.comp.4_stats.csv
# processing class: 104.comp.5_stats.csv
# processing class: 104.comp.6_stats.csv
# processing class: 104.comp.7_stats.csv
# processing class: 104.comp.8_stats.csv
# processing class: 104.comp.9_stats.csv
# processing class: 104.comp.10_stats.csv
# processing class: 104.comp.11_stats.csv
# processing class: 104.comp.12_stats.csv
# processing class: 104.comp.13_stats.csv
# processing class: 104.comp.14_stats.csv
# processing class: 104.comp.15_stats.csv
# processing class: 104.comp.16_stats.csv
# processing class: 104.comp.17_stats.csv
# processing class: 104.comp.18_stats.csv
# processing class: 104.comp.19_stats.csv
# processing class: 104.comp.20_stats.csv
# processing class: 104.comp.21_stats.csv
# processing class: 104.comp.22_stats.csv
# processing class: 104.ply
# processing class: 104.txt
# processing class: 202.comp.1_stats.csv
# processing class: 202.comp.2_stats.csv
# processing class: 202.comp.3_stats.csv
# processing class: 202.comp.4_stats.csv
# processing class: 202.comp.5_stats.csv
# processing class: 202.comp.6_stats.csv
# processing class: 202.comp.7_stats.csv
# processing class: 202.comp.8_stats.csv
# processing class: 202.comp.9_stats.csv
# processing class: 202.comp.10_stats.csv
# processing class: 202.comp.11_stats.csv
# processing class: 202.comp.12_stats.csv
# processing class: 202.comp.13_stats.csv
# processing class: 202.comp.14_stats.csv
# processing class: 202.comp.15_stats.csv
# processing class: 202.comp.16_stats.csv
# processing class: 202.comp.17_stats.csv
# processing class: 202.comp.18_stats.csv
# processing class: 202.comp.19_stats.csv
# processing class: 202.comp.20_stats.csv
# processing class: 202.comp.21_stats.csv
# processing class: 202.ply
# processing class: 202.txt
# processing class: 207.comp.1_stats.csv
# processing class: 207.comp.2_stats.csv
# processing class: 207.comp.3_stats.csv
# processing class: 207.comp.4_stats.csv
# processing class: 207.comp.5_stats.csv
# processing class: 207.comp.6_stats.csv
# processing class: 207.comp.7_stats.csv
# processing class: 207.comp.8_stats.csv
# processing class: 207.comp.9_stats.csv
# processing class: 207.comp.10_stats.csv
# processing class: 207.comp.11_stats.csv
# processing class: 207.comp.12_stats.csv
# processing class: 207.comp.13_stats.csv
# processing class: 207.comp.14_stats.csv
# processing class: 207.comp.15_stats.csv
# processing class: 207.comp.16_stats.csv
# processing class: 207.comp.17_stats.csv
# processing class: 207.comp.18_stats.csv
# processing class: 207.ply
# processing class: 207.txt
# processing class: 689.comp.1_stats.csv
# processing class: 689.comp.2_stats.csv
# processing class: 689.comp.3_stats.csv
# processing class: 689.comp.4_stats.csv
# processing class: 689.comp.5_stats.csv
# processing class: 689.comp.6_stats.csv
# processing class: 689.comp.7_stats.csv
# processing class: 689.ply
# processing class: 689.txt
# processing class: 691.comp.1_stats.csv
# processing class: 691.comp.2_stats.csv
# processing class: 691.comp.3_stats.csv
# processing class: 691.comp.4_stats.csv
# processing class: 691.comp.5_stats.csv
# processing class: 691.comp.6_stats.csv
# processing class: 691.comp.7_stats.csv
# processing class: 691.ply
# processing class: 691.txt
# processing class: 695.comp.1_stats.csv
# processing class: 695.comp.2_stats.csv
# processing class: 695.comp.3_stats.csv
# processing class: 695.comp.4_stats.csv
# processing class: 695.comp.5_stats.csv
# processing class: 695.comp.6_stats.csv
# processing class: 695.comp.7_stats.csv
# processing class: 695.comp.8_stats.csv
# processing class: 695.comp.9_stats.csv
# processing class: 695.comp.10_stats.csv
# processing class: 695.comp.11_stats.csv
# processing class: 695.comp.12_stats.csv
# processing class: 695.comp.13_stats.csv
# processing class: 695.comp.14_stats.csv
# processing class: 695.comp.15_stats.csv
# processing class: 695.ply
# processing class: 695.txt
# processing class: 700.comp.1_stats.csv
# processing class: 700.comp.2_stats.csv
# processing class: 700.comp.3_stats.csv
# processing class: 700.comp.4_stats.csv
# processing class: 700.comp.5_stats.csv
# processing class: 700.comp.6_stats.csv
# processing class: 700.comp.7_stats.csv
# processing class: 700.comp.8_stats.csv
# processing class: 700.comp.9_stats.csv
# processing class: 700.comp.10_stats.csv
# processing class: 700.comp.11_stats.csv
# processing class: 700.comp.12_stats.csv
# processing class: 700.comp.13_stats.csv
# processing class: 700.comp.14_stats.csv
# processing class: 700.comp.15_stats.csv
# processing class: 700.ply
# processing class: 700.txt
# processing class: 709.comp.1_stats.csv
# processing class: 709.comp.2_stats.csv
# processing class: 709.comp.3_stats.csv
# processing class: 709.comp.4_stats.csv
# processing class: 709.comp.5_stats.csv
# processing class: 709.comp.6_stats.csv
# processing class: 709.comp.7_stats.csv
# processing class: 709.comp.8_stats.csv
# processing class: 709.comp.9_stats.csv
# processing class: 709.ply
# processing class: 709.txt
# processing class: 710.comp.1_stats.csv
# processing class: 710.comp.2_stats.csv
# processing class: 710.comp.3_stats.csv
# processing class: 710.comp.4_stats.csv
# processing class: 710.comp.5_stats.csv
# processing class: 710.comp.6_stats.csv
# processing class: 710.ply
# processing class: 710.txt
# processing class: 713.comp.1_stats.csv
# processing class: 713.comp.2_stats.csv
# processing class: 713.comp.3_stats.csv
# processing class: 713.comp.4_stats.csv
# processing class: 713.comp.5_stats.csv
# processing class: 713.comp.6_stats.csv
# processing class: 713.comp.7_stats.csv
# processing class: 713.ply
# processing class: 713.txt
# processing class: 720.comp.1_stats.csv
# processing class: 720.comp.2_stats.csv
# processing class: 720.comp.3_stats.csv
# processing class: 720.comp.4_stats.csv
# processing class: 720.comp.5_stats.csv
# processing class: 720.comp.6_stats.csv
# processing class: 720.comp.7_stats.csv
# processing class: 720.comp.8_stats.csv
# processing class: 720.comp.9_stats.csv
# processing class: 720.comp.10_stats.csv
# processing class: 9433.comp.13_stats.csv
# processing class: 9433.comp.14_stats.csv
# processing class: 9433.comp.15_stats.csv
# processing class: 9433.comp.16_stats.csv
# processing class: 9433.comp.17_stats.csv
# processing class: 9433.comp.18_stats.csv
# processing class: 9433.comp.19_stats.csv
# processing class: 9433.comp.20_stats.csv
# processing class: 9433.ply
# processing class: 9433.txt
# processing class: 10350.comp.1_stats.csv
# processing class: 10350.comp.2_stats.csv
# processing class: 10350.comp.3_stats.csv
# processing class: 10350.comp.4_stats.csv
# processing class: 10350.comp.5_stats.csv
# processing class: 10350.comp.6_stats.csv
# processing class: 10350.comp.7_stats.csv
# processing class: 10350.comp.8_stats.csv
# processing class: 10350.comp.9_stats.csv
# processing class: 10350.comp.10_stats.csv
# processing class: 10350.comp.11_stats.csv
# processing class: 10350.comp.12_stats.csv
# processing class: 10350.comp.13_stats.csv
# processing class: 10350.comp.14_stats.csv
# processing class: 10350.comp.15_stats.csv
# processing class: 10350.comp.16_stats.csv
# processing class: 10350.ply
# processing class: 10350.txt
# processing class: 10354.comp.1_stats.csv
# processing class: 10354.comp.2_stats.csv
# processing class: 10354.comp.3_stats.csv
# processing class: 10354.comp.4_stats.csv
# processing class: 10354.comp.5_stats.csv
# processing class: 10354.comp.6_stats.csv
# processing class: 10354.comp.7_stats.csv
# processing class: 10354.comp.8_stats.csv
# processing class: 10354.comp.9_stats.csv
# processing class: 10354.comp.10_stats.csv
# processing class: 10354.comp.11_stats.csv
# processing class: 10354.comp.12_stats.csv
# processing class: 10354.comp.13_stats.csv
# processing class: 10354.ply
# processing class: 10354.txt
# processing class: 10356.comp.1_stats.csv
# processing class: 10356.comp.2_stats.csv
# processing class: 10356.comp.3_stats.csv
# processing class: 10356.comp.4_stats.csv
# processing class: 10356.comp.5_stats.csv
# processing class: 10356.comp.6_stats.csv
# processing class: 10356.comp.7_stats.csv
# processing class: 10356.ply
# processing class: 10356.txt
# processing class: 10358.comp.1_stats.csv
# processing class: 10358.comp.2_stats.csv
# processing class: 10358.comp.3_stats.csv
# processing class: 10358.comp.4_stats.csv
# processing class: 10358.comp.5_stats.csv
# processing class: 10358.comp.6_stats.csv
# processing class: 10358.comp.7_stats.csv
# processing class: 10358.comp.8_stats.csv
# processing class: 10358.comp.9_stats.csv
# processing class: 10358.comp.10_stats.csv
# processing class: 10358.comp.11_stats.csv
# processing class: 10358.comp.12_stats.csv
# processing class: 10358.comp.13_stats.csv
# processing class: 10358.comp.14_stats.csv
# processing class: 10358.comp.15_stats.csv
# processing class: 10358.ply
# processing class: 10358.txt
# processing class: 10360.comp.1_stats.csv
# processing class: 10360.comp.2_stats.csv
# processing class: 10360.comp.3_stats.csv
# processing class: 10360.comp.4_stats.csv
# processing class: 10360.comp.5_stats.csv
# processing class: 10360.comp.6_stats.csv
# processing class: 10360.comp.7_stats.csv
# processing class: 10360.comp.8_stats.csv
# processing class: 10360.comp.9_stats.csv
# processing class: 10360.comp.10_stats.csv
# processing class: 10360.ply
# processing class: 10360.txt
# processing class: 10361.comp.1_stats.csv
# processing class: 10361.comp.2_stats.csv
# processing class: 10361.comp.3_stats.csv
# processing class: 10361.comp.4_stats.csv
# processing class: 10361.comp.5_stats.csv
# processing class: 10361.comp.6_stats.csv
# processing class: 10361.comp.7_stats.csv
# processing class: 10361.comp.8_stats.csv
# processing class: 10361.comp.9_stats.csv
# processing class: 10361.comp.10_stats.csv
# processing class: 10361.comp.11_stats.csv
# processing class: 10361.comp.12_stats.csv
# processing class: 10361.comp.13_stats.csv
# processing class: 10361.comp.14_stats.csv
# processing class: 10361.comp.15_stats.csv
# processing class: 10361.comp.16_stats.csv
# processing class: 10361.ply
# processing class: 10361.txt
# processing class: 10454.comp.1_stats.csv
# processing class: 10454.comp.2_stats.csv
# processing class: 10454.comp.3_stats.csv
# processing class: 10454.comp.4_stats.csv
# processing class: 10454.comp.5_stats.csv
# processing class: 10454.comp.6_stats.csv
# processing class: 10454.comp.7_stats.csv
# processing class: 10454.comp.8_stats.csv
# processing class: 10454.comp.9_stats.csv
# processing class: 10454.comp.10_stats.csv
# processing class: 10454.comp.11_stats.csv
# processing class: 10454.comp.12_stats.csv
# processing class: 10454.comp.13_stats.csv
# processing class: 10454.comp.14_stats.csv
# processing class: 10454.comp.15_stats.csv
# processing class: 10454.comp.16_stats.csv
# processing class: 10454.comp.17_stats.csv
# processing class: 10454.comp.18_stats.csv
# processing class: 10454.comp.19_stats.csv
# processing class: 10454.ply
# processing class: 10454.txt
# processing class: scars
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 5>()
#       2 NUM_CLASSES = 1
#       3 BATCH_SIZE = 32
# ----> 5 train_points, test_points, train_labels, test_labels, CLASS_MAP = parse_dataset(
#       6     NUM_POINTS
#       7 )
#
# Input In [9], in parse_dataset(num_points)
#      16 test_files = glob.glob(os.path.join(folder, "test/*"))
#      18 for f in train_files:
# ---> 19     train_points.append(trimesh.load(f).sample(num_points))
#      20     train_labels.append(i)
#      22 for f in test_files:
#
# AttributeError: 'Scene' object has no attribute 'sample'

# %%
def augment(points, label):
    # jitter points
    points += tf.random.uniform(points.shape, -0.005, 0.005, dtype=tf.float64)
    # shuffle points
    points = tf.random.shuffle(points)
    return points, label


train_dataset = tf.data.Dataset.from_tensor_slices((train_points, train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_points, test_labels))

train_dataset = train_dataset.shuffle(len(train_points)).map(augment).batch(BATCH_SIZE)
test_dataset = test_dataset.shuffle(len(test_points)).batch(BATCH_SIZE)
# Out:
# 2022-07-12 17:12:25.649540: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-12 17:12:25.649563: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (linsel-ThinkPad-P15-Gen-2i): /proc/driver/nvidia/version does not exist
# 2022-07-12 17:12:25.649955: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def conv_bn(x, filters):
    x = layers.Conv1D(filters, kernel_size=1, padding="valid")(x)
    x = layers.BatchNormalization(momentum=0.0)(x)
    return layers.Activation("relu")(x)


def dense_bn(x, filters):
    x = layers.Dense(filters)(x)
    x = layers.BatchNormalization(momentum=0.0)(x)
    return layers.Activation("relu")(x)

# %%
class OrthogonalRegularizer(keras.regularizers.Regularizer):
    def __init__(self, num_features, l2reg=0.001):
        self.num_features = num_features
        self.l2reg = l2reg
        self.eye = tf.eye(num_features)

    def __call__(self, x):
        x = tf.reshape(x, (-1, self.num_features, self.num_features))
        xxt = tf.tensordot(x, x, axes=(2, 2))
        xxt = tf.reshape(xxt, (-1, self.num_features, self.num_features))
        return tf.reduce_sum(self.l2reg * tf.square(xxt - self.eye))

# %%
def tnet(inputs, num_features):

    # Initalise bias as the indentity matrix
    bias = keras.initializers.Constant(np.eye(num_features).flatten())
    reg = OrthogonalRegularizer(num_features)

    x = conv_bn(inputs, 32)
    x = conv_bn(x, 64)
    x = conv_bn(x, 512)
    x = layers.GlobalMaxPooling1D()(x)
    x = dense_bn(x, 256)
    x = dense_bn(x, 128)
    x = layers.Dense(
        num_features * num_features,
        kernel_initializer="zeros",
        bias_initializer=bias,
        activity_regularizer=reg,
    )(x)
    feat_T = layers.Reshape((num_features, num_features))(x)
    # Apply affine transformation to input features
    return layers.Dot(axes=(2, 1))([inputs, feat_T])

# %%
inputs = keras.Input(shape=(NUM_POINTS, 3))

x = tnet(inputs, 3)
x = conv_bn(x, 32)
x = conv_bn(x, 32)
x = tnet(x, 32)
x = conv_bn(x, 32)
x = conv_bn(x, 64)
x = conv_bn(x, 512)
x = layers.GlobalMaxPooling1D()(x)
x = dense_bn(x, 256)
x = layers.Dropout(0.3)(x)
x = dense_bn(x, 128)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = keras.Model(inputs=inputs, outputs=outputs, name="pointnet")
model.summary()
# Out:
# Model: "pointnet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 2048, 3)]    0           []
#
#  conv1d_11 (Conv1D)             (None, 2048, 32)     128         ['input_2[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 2048, 32)    128         ['conv1d_11[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 2048, 32)     0           ['batch_normalization_17[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 2048, 64)     2112        ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 2048, 64)    256         ['conv1d_12[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 2048, 64)     0           ['batch_normalization_18[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 2048, 512)    33280       ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 2048, 512)   2048        ['conv1d_13[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 2048, 512)    0           ['batch_normalization_19[0][0]']
#
#  global_max_pooling1d_3 (Global  (None, 512)         0           ['activation_19[0][0]']
#  MaxPooling1D)
#
#  dense_9 (Dense)                (None, 256)          131328      ['global_max_pooling1d_3[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 256)         1024        ['dense_9[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 256)          0           ['batch_normalization_20[0][0]']
#
#  dense_10 (Dense)               (None, 128)          32896       ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 128)         512         ['dense_10[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 128)          0           ['batch_normalization_21[0][0]']
#
#  dense_11 (Dense)               (None, 9)            1161        ['activation_21[0][0]']
#
#  reshape_2 (Reshape)            (None, 3, 3)         0           ['dense_11[0][0]']
#
#  dot_2 (Dot)                    (None, 2048, 3)      0           ['input_2[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 2048, 32)     128         ['dot_2[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 2048, 32)    128         ['conv1d_14[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 2048, 32)     0           ['batch_normalization_22[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 2048, 32)     1056        ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 2048, 32)    128         ['conv1d_15[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 2048, 32)     0           ['batch_normalization_23[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 2048, 32)     1056        ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 2048, 32)    128         ['conv1d_16[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 2048, 32)     0           ['batch_normalization_24[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 2048, 64)     2112        ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 2048, 64)    256         ['conv1d_17[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 2048, 64)     0           ['batch_normalization_25[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 2048, 512)    33280       ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 2048, 512)   2048        ['conv1d_18[0][0]']
#  ormalization)
#  activation_26 (Activation)     (None, 2048, 512)    0           ['batch_normalization_26[0][0]']
#
#  global_max_pooling1d_4 (Global  (None, 512)         0           ['activation_26[0][0]']
#  MaxPooling1D)
#
#  dense_12 (Dense)               (None, 256)          131328      ['global_max_pooling1d_4[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 256)         1024        ['dense_12[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 256)          0           ['batch_normalization_27[0][0]']
#
#  dense_13 (Dense)               (None, 128)          32896       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 128)         512         ['dense_13[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 128)          0           ['batch_normalization_28[0][0]']
#
#  dense_14 (Dense)               (None, 1024)         132096      ['activation_28[0][0]']
#
#  reshape_3 (Reshape)            (None, 32, 32)       0           ['dense_14[0][0]']
#
#  dot_3 (Dot)                    (None, 2048, 32)     0           ['activation_23[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 2048, 32)     1056        ['dot_3[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 2048, 32)    128         ['conv1d_19[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 2048, 32)     0           ['batch_normalization_29[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 2048, 64)     2112        ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 2048, 64)    256         ['conv1d_20[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 2048, 64)     0           ['batch_normalization_30[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 2048, 512)    33280       ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 2048, 512)   2048        ['conv1d_21[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 2048, 512)    0           ['batch_normalization_31[0][0]']
#
#  global_max_pooling1d_5 (Global  (None, 512)         0           ['activation_31[0][0]']
#  MaxPooling1D)
#
#  dense_15 (Dense)               (None, 256)          131328      ['global_max_pooling1d_5[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 256)         1024        ['dense_15[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 256)          0           ['batch_normalization_32[0][0]']
#
#  dropout_2 (Dropout)            (None, 256)          0           ['activation_32[0][0]']
#
#  dense_16 (Dense)               (None, 128)          32896       ['dropout_2[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 128)         512         ['dense_16[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 128)          0           ['batch_normalization_33[0][0]']
#
#  dropout_3 (Dropout)            (None, 128)          0           ['activation_33[0][0]']
#
#  dense_17 (Dense)               (None, 10)           1290        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 748,979
# Trainable params: 742,899
# Non-trainable params: 6,080
# __________________________________________________________________________________________________

# %%
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics=["sparse_categorical_accuracy"],
)

model.fit(train_dataset, epochs=4, validation_data=test_dataset)
# Out:
# Epoch 1/4
# 125/125 [==============================] - 155s 1s/step - loss: 2.5560 - sparse_categorical_accuracy: 0.5495 - val_loss: 40811646976.0000 - val_sparse_categorical_accuracy: 0.4802
# Epoch 2/4
# 125/125 [==============================] - 151s 1s/step - loss: 2.3484 - sparse_categorical_accuracy: 0.6046 - val_loss: 572456930639872.0000 - val_sparse_categorical_accuracy: 0.6267
# Epoch 3/4
# 125/125 [==============================] - 145s 1s/step - loss: 2.1319 - sparse_categorical_accuracy: 0.6617 - val_loss: 5.1492 - val_sparse_categorical_accuracy: 0.5374
# Epoch 4/4
# 125/125 [==============================] - 142s 1s/step - loss: 2.0768 - sparse_categorical_accuracy: 0.6908 - val_loss: 4228021248.0000 - val_sparse_categorical_accuracy: 0.5848

# %%
data = test_dataset.take(1)

points, labels = list(data)[0]
points = points[:8, ...]
labels = labels[:8, ...]

# run test data through model
preds = model.predict(points)
preds = tf.math.argmax(preds, -1)

points = points.numpy()

# plot points with predicted class and label
fig = plt.figure(figsize=(15, 10))
for i in range(8):
    ax = fig.add_subplot(2, 4, i + 1, projection="3d")
    ax.scatter(points[i, :, 0], points[i, :, 1], points[i, :, 2])
    ax.set_title(
        "pred: {:}, label: {:}".format(
            CLASS_MAP[preds[i].numpy()], CLASS_MAP[labels.numpy()[i]]
        )
    )
    ax.set_axis_off()
plt.show()
# Out:
# 1/1 [==============================] - 0s 357ms/step
