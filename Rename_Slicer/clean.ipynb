# %%
from enumerate_labels import read_label_txt,write_header,write_enumerated_labels_txt_file,write_sorted_labels_txt_file,write_sorted_labels_txt_file_switch

from Cleaning.clean_gt import clean_gt

path = '/home/linsel/Documents/PhD/Data/Fumane/annotated/coloured/curvature/orientation/'#new/selected/'

####################################
# path to build gigamesh folder
giga_path = "~/Downloads/build-GigaMesh-Desktop_Qt_5_15_2_GCC_64bit-Debug/cli/"
method = "./gigamesh-clean"


import os

# %%
os.chdir(path)

os.system(giga_path + method + ' *.ply')
# Out:
# [GigaMesh] ----------------------------------------------------------------------------------
# [GigaMesh] Package version: 220530
# [GigaMesh] ..................................................................................
# [GigaMesh] Built by: linsel@linsel-ThinkPad-P15-Gen-2i
# [GigaMesh] ..... on: 19.Jul.22
# [GigaMesh] .... for: IWR Open Source
# [GigaMesh] Git SHA1: 72419847468e12dd8d70cc4a8f0068c5553027b8
# [GigaMesh] ----------------------------------------------------------------------------------
# [GigaMesh] Holes consisting of more than 3000 vertices/edges are not attempted to be filled.
# [GigaMesh] Surfaces with an area less than 10% of the total surface will be removed.
# [GigaMesh] ----------------------------------------------------------------------------------
# [GigaMesh] Processing file 10350_r1.00_n4_v256.volume.ply...
# [Mesh] Construct Mesh --- Begin.
# [PlyReader::readFile] opening: '"10350_r1.00_n4_v256.volume.ply"'
# ...
