# %%
from enumerate_labels import read_label_txt,write_header,write_enumerated_labels_txt_file,write_sorted_labels_txt_file,write_sorted_labels_txt_file_switch

from Cleaning.clean_gt import clean_gt

# %%
path = '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/'#new/selected/'
path = '/home/linsel/Documents/PhD/Data/Fumane/annotated/coloured/'#new/selected/'
# path = '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/new/selected/'
paths = ['/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/selected/',
        '/media/linsel/3931-6632/data/phd stone tools/Blades_Bladelets_PLY/annotated/coloured/new/selected/']



####################################
# path to build gigamesh folder
giga_path = "~/Downloads/build-GigaMesh-Desktop_Qt_5_15_2_GCC_64bit-Debug/cli/"
method = "./gigamesh-meshsplit"


import os

# %%
from os import listdir
from os.path import isfile, join

from read_ply import read_ply

files = os.listdir(path)

for gt_filename in files:

    if gt_filename.endswith(".ply"):
        print(gt_filename)
        #######################################
        # create label file and split the labels 

         # "./gigamesh-meshsplit"
        
        gt_filename_notxt = path + gt_filename[:-4]

        gt_label,_ = read_ply(path + gt_filename)
        write_sorted_labels_txt_file(gt_label, gt_filename_notxt)
        
#         print(giga_path + method + ' "' + path + gt_filename + '" --recursive-iteration')
        
#         os.system(giga_path + method + ' "' + path + gt_filename + '" --recursive-iteration')#

        ########################################
        # calculate feature-vectors 
        
#         method = "./gigamesh-meshsplit" # "./gigamesh-meshsplit"        
#         os.system(giga_path + method + ' "' + path + gt_filename + '" -r')#
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [16], in <cell line: 6>()
#       2 from os.path import isfile, join
#       4 from read_ply import read_ply
# ----> 6 files = os.listdir(path)
#       8 for gt_filename in files:
#      10     if gt_filename.endswith(".ply"):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/Documents/PhD/Data/Fumane/annotated/coloured/'

# %%
os.system(giga_path + method + ' "' + path +  '*.ply" --recursive-iteration')
# Out:
# [GigaMesh] ----------------------------------------------------------------------------------
# [GigaMesh] Package version: 220530
# [GigaMesh] ..................................................................................
# [GigaMesh] Built by: linsel@linsel-ThinkPad-P15-Gen-2i
# [GigaMesh] ..... on: 19.Jul.22
# [GigaMesh] .... for: IWR Open Source
# [GigaMesh] Git SHA1: 72419847468e12dd8d70cc4a8f0068c5553027b8
# [GigaMesh] ----------------------------------------------------------------------------------
# [GigaMesh] Processing file "/home/linsel/Documents/PhD/Data/Fumane/annotated/coloured/700_c.ply"...
# [GigaMesh] File IN:         "/home/linsel/Documents/PhD/Data/Fumane/annotated/coloured/700_c.ply"
# [Mesh] Construct Mesh --- Begin.
# [PlyReader::readFile] opening: '"/home/linsel/Documents/PhD/Data/Fumane/annotated/coloured/700_c.ply"'
# [PlyReader::parseAscii] Reading vertices done.
# [PlyReader::parseAscii] Reading faces done.
# ...

# %%
method = "./gigamesh-featurevectors"

os.chdir(path)

os.system(giga_path + method + ' -r 1 ' + '*.ply')
# Out:
# [GigaMesh] ----------------------------------------------------------------------------------
# [GigaMesh] Package version: 220530
# [GigaMesh] ..................................................................................
# [GigaMesh] Built by: linsel@linsel-ThinkPad-P15-Gen-2i
# [GigaMesh] ..... on: 19.Jul.22
# [GigaMesh] .... for: IWR Open Source
# [GigaMesh] Git SHA1: 72419847468e12dd8d70cc4a8f0068c5553027b8
# [GigaMesh] ----------------------------------------------------------------------------------
# [GigaMesh] Processing file 10350_c.ply...
# [Mesh] Construct Mesh --- Begin.
# [PlyReader::readFile] opening: '"10350_c.ply"'
# [PlyReader::parseAscii] Reading vertices done.
# [PlyReader::parseAscii] Reading faces done.
# [PlyReader::parseAscii] Reading polylines done.
# [Thread 1] estMultiFaceConnection --- Begin.
# [Thread 1] estMultiFaceConnection --- Done. Processing took 0.71 seconds.
# [Mesh] ============================================= FAST ===
# ...

# %% [markdown]
# # One File

# %%
from read_ply import read_ply

#gt_filename = "Data/SerieFinal/groundtruths/31_c.ply"
gt_filename_notxt = path + name + ""

gt_label,_ = read_ply(gt_filename)
#write_sorted_labels_txt_file(gt_label, gt_filename_notxt)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from read_ply import read_ply
#       3 #gt_filename = "Data/SerieFinal/groundtruths/31_c.ply"
#       4 gt_filename_notxt = path + name + ""
#
# ModuleNotFoundError: No module named 'read_ply'
