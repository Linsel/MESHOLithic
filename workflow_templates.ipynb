# %%
import json

templates = {
'GMAO':{  
	'name':'GMAO',
	'procedure': 'GigaMesh', 
	'stage':'',
	'method':'',
	'parameters':'',
	'variables': '',                         
	'processed':'_GMAO',
	'metadata':['']},
'GMCF':{ 
	'name':'GMCF',
	'procedure': 'GigaMesh', 
	'stage':'',
	'method':'gigamesh-clean', 
	'variables': {},             
	'parameters':'-m "original, lithic"',
	'processed':'_GMCF',
	'metadata':['mesh_polish']},    
'MSII':{
	'name':'MSII',
	'procedure': 'GigaMesh', 
	'stage':'',
	'method':'gigamesh-featurevectors',
	'variables': {	'r':1.00,
			'n':4,
			'v':256},                 
	'parameters':'-r 1.00 -n 4 -l 256',
	'processed':'_r1.00_n4_v256.volume',
	'metadata':['info','normal','surface','volume']},
'CO_concavity':{
	'name':'CO_concavity',
	'procedure': 'MSII',
    'method': 'CO_concavity',
	'stage':'',
	'parameters':'',
	'variables':{	'graphname':'max',
					'diameter': 1.00,
					'parameter':'quality',
					'n_rad': 16},                        
	'processed':'',
	'labelname':'_scar-labels',
	'metadata':['']},
'color_to_labels':{
	'name':'ridge_color_to_scar_labels',
	'procedure': 'transform_labelledmesh',
	'method': 'ridge_color_to_scar_labels',
	'stage':'',
	'parameters':'',
	'variables':{'tresh': 20,'ending': '.ply'},
	'processed': '_GMCF_c',
	'metadata':['_CC-labels','_scar-labels']}
	} 



{1:{'name': 'GMAO',         "derived_from": "MEAS", 'class': 'GigaMesh', 'method': '',                'stage': 1, 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
 2:{'name': 'GMCF',         "derived_from": "GMAO", 'class': 'GigaMesh', 'method': 'gigamesh-clean',  'stage': 2, 'add_labels' : False, 'variables': {}, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
 3:{'name': 'MSII',         "derived_from": "GMCF", 'class': '',         'method': '',                'stage': 3, 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
 4:{"name": "CO_Concavity", "derived_from": 'MSII', "class": "CO-MSII",  "method": "CO_concavity",    "stage": 4, "parameters": "", 'add_labels' : True, 'add_links': True, "variables": {"labelname": "_scar-labels","graphname": "max", "diameter": 1, "parameters": ["quality"], "n_rad": 4, "preprocessed":""}, "processed": "", "labelname": "_scar-labels"},"metadata": []}

{1:{'name': 'GMAO', "derived_from": "MEAS", 'class': 'GigaMesh', 'method': '', 'stage': 1, 'parameters': '', 'variables': '', 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
 2:{'name': 'GMCF', "derived_from": "GMAO", 'class': 'GigaMesh', 'method': 'gigamesh-clean', 'stage': 2, 'variables': {}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
 3:{'name': 'MSII', "derived_from": "GMCF", 'class': '', 'method': '', 'stage': 3, 'variables': {'r': 1.0, 'n': 4, 'v': 256}, 'parameters': '-r 1.00 -n 4 -l 256', 'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
 4:{'name': 'CO_MSII', "derived_from": "MSII",'class':'CO-MSII-fv', 'method':'MSII_feature_vector', 'stage':4, 'parameters':'', 'add_labels' : True, 'add_links': True, 'variables':{'labelname':'_scar-labels', "graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''},'metadata': []}}})

{1:{'name': 'GMAO',   'stage': 1, 'class': 'GigaMesh', 'method': '',                 'parameters': '',                    'variables': {''}, 'add_labels' : False, 'processed': '_GMAO', 'metadata': ['']},
 2:{'name': 'GMCF',   'stage': 2, 'class': 'GigaMesh', 'method': 'gigamesh-clean',   'parameters': '',                    'variables': {''}, 'add_labels' : False, 'parameters': '-m "original, lithic"', 'processed': '_GMCF', 'metadata': ['mesh_polish']},
 3:{'name': 'MSII',   'stage': 3, 'class': '',         'method': '',                 'parameters': '-r 1.00 -n 4 -l 256', 'variables': {'r': 1.0, 'n': 4, 'v': 256},  'add_labels' : False, 'processed': '_r1.00_n4_v256.volume', 'metadata': ['info', 'normal', 'surface', 'volume']},
 4:{'name': 'MSII_1D','stage':4,  'class':'CO-MSII',   'method': 'MSII',             'parameters':'',                     'variables':{'labelname':'_scar-labels', "graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''}, 'add_labels' : True, 'add_links': True, "metadata": [""]}}


workflow_template_file = ''.join(['workflow_templates.json'])

with open(workflow_template_file,"w") as f:
	json.dump(templates,f)

with open(workflow_template_file,"w") as f:
	json.dump(templates,f)

# %%
# 'class':'labelledmesh'

{'stage':'','class':'labelledmesh','name':'ridge_prepare','method':'ridge_prepare','variables':{'labelname':'scar-labels','preprocessed':''}}

{'stage':'','class':'labelledmesh','name':'kmeans_label','method':'kmeans_label','variables':{'labelname':'scar-labels'},'metadata':'Kmeans-labels'}
{'stage':'','class':'labelledmesh','name':'kmeans_sclice','method':'kmeans_sclice','variables':{'labelname':'scar-labels','preprocessed':''},'metadata':['Kmeans-cl-1-label','Kmeans-cl-2-label'],['Kmeans-cl-1','Kmeans-cl-2']}
# {'stage':'','class':'labelledmesh','name':'label_slice','method':'label_slice','variables':{'labelname':'scar-labels'}}
{'stage':'','class':'labelledmesh','name':'direct_graph_area','method':'direct_graph_area','variables':{'labelname':'scar-labels','preprocessed':''},'metadata':['_links','_eval_links']}
{'stage':'','class':'labelledmesh','name':'export_ridges_mesh','method':'export_ridges_mesh','variables':{'labelname':'scar-labels','preprocessed':''},'metadata':['_ridges']}
# {'stage':'','class':'labelledmesh','name':'submeshes','method':'submeshes','variables':{'labelname':'scar-labels','preprocessed':''}}
# {'stage':'','class':'labelledmesh','name':'submeshes_properties','method':'submeshes_properties','variables':{'labelname':'scar-labels','preprocessed':''}}

# 'transform_labelledmesh'
{'stage':'','class':'transform_labelledmesh','name':'scar_to_ridge_labels_binary','method':'scar_to_ridge_labels_binary','variables':{'tresh': 20,'ending': '.ply','preprocessed': ''}}
{'stage':'','class':'transform_labelledmesh','name':'scar_to_ridge_labels_CC','method':'scar_to_ridge_labels_CC','variables':{'tresh': 20,'ending': '.ply','preprocessed': ''}}
{'stage':'','class':'transform_labelledmesh','name':'ridge_CC_to_scar_labels','method':'ridge_CC_to_scar_labels','variables':{'tresh': 20,'ending': '.ply','preprocessed': ''}}
{'stage':'','class':'transform_labelledmesh','name':'ridge_color_to_scar_labels','method':'ridge_color_to_scar_labels','variables':{'tresh': 20,'ending': '.ply','preprocessed': ''}}

# CO-MSII

{'stage':'','class':'CO-MSII','name':'CO_prepare','method':'CO_prepare','variables':{'labelname':'scar-labels',"graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''}}
{'stage':'','class':'CO-MSII','name':'MSII','method':'MSII','variables':{'labelname':'scar-labels',"graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''}}
{'stage':'','class':'CO-MSII','name':'MSII_feature_vector','method':'MSII_feature_vector','variables':{'labelname':'scar-labels',"graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16,'preprocessed':''}}


{'stage':'','class':'CO-MSII','name':'CO_concavity','method':'CO_concavity','variables':{"graphname": "max", "diameter": 1.0, "parameter": "quality", "n_rad": 16, "preprocessed":""}}

# Graph
{'stage':'','class':'graph','name':'undirected_graph','method':'undirected_graph','variables':{,'preprocessed':'','labelname':''}}
{'stage':'','class':'graph','name':'graph_evaluation','method':'graph_evaluation','variables':{,'preprocessed':'','labelname':,'','radius_scale':0.5,'circumference_scale':1}}
{'stage':'','class':'graph','name':'graph_direct_parameter','method':'graph_direct_parameter','variables':{,'preprocessed':'','labelname':''}}
{'stage':'','class':'graph','name':'direct_graph','method':'direct_graph','variables':{,'preprocessed':'','labelname':''}}

    


#
    path = kwargs ['path'] 
    id = kwargs ['id']
    preprocessed = kwargs ['preprocessed']
    diameter = kwargs ['diameter'] 
    parameters = kwargs ['parameters'] 
    n_rad = kwargs ['n_rad'] 
    obj.graphname = kwargs ['graphname']


{'stage':'','class':'CO','name':'edge_to_arrow','method':'edge_to_arrow','variables':{,'preprocessed':''}}
#
# 'GigaMesh':
# Out:
#   Input In [3]
#     {'','class':'labelledmesh','name':'ridge_prepare','method':'ridge_prepare','variables':{'labelname':'scar-labels','preprocessed':''}}
#                ^
# SyntaxError: invalid syntax
